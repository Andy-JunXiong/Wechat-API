# %%
import itchat

# 获取数据
def get_data():
    # 扫描二维码登陆微信，实际上就是通过网页版微信登陆
    itchat.auto_login()
    # 获取所有好友信息
    friends = itchat.get_friends(update=True)  # 返回一个包含用户信息字典的列表
    return friends

if __name__ == '__main__':
    print(get_data())
# Out:
# █
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as WAKE UP
# [<User: {'DisplayName': '', 'UniFriend': 0, 'RemarkPYQuanPin': '', 'KeyWord': 'chr', 'UserName': '@d7d84d1a0c1e274d4eaf8dae20558c29', 'AppAccountFlag': 0, 'Uin': 239757095, 'HideInputBarFlag': 0, 'Signature': '斯人若彩虹，遇见方知有。', 'EncryChatRoomId': '', 'PYQuanPin': 'WAKEUP', 'ContactFlag': 2055, 'PYInitial': 'WAKEUP', 'OwnerUin': 0, 'RemarkName': '', 'NickName': 'WAKE UP', 'Sex': 1, 'StarFriend': 0, 'SnsFlag': 49, 'AttrStatus': 2147610727, 'WebWxPluginSwitch': 1, 'Alias': '', 'ChatRoomId': 0, 'City': '', 'IsOwner': 0, 'MemberList': <ContactList: []>, 'Statues': 0, 'RemarkPYInitial': '', 'Province': 'New South Wales', 'VerifyFlag': 0, 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=709293290&username=@d7d84d1a0c1e274d4eaf8dae20558c29&skey=@crypt_b1692417_7bcbe32e877bef06be2fe1f3b276ee08', 'MemberCount': 0, 'HeadImgFlag': 1}>, <User: {'DisplayName': '', 'UniFriend': 0, 'RemarkPYQuanPin': 'spanclassemojiemoji1f433spanlaopo', 'Statues': 0, 'UserName': '@7a4141ef1c4a06380613134783fa6f29e6a099833b0371c747bdb02939d4966a', 'AppAccountFlag': 0, 'Uin': 0, 'HideInputBarFlag': 0, 'Signature': '海蓝时见<span class="emoji emoji1f433"></span>', 'EncryChatRoomId': '', 'PYQuanPin': 'spanclassemojiemoji1f433span', 'ContactFlag': 2051, 'PYInitial': 'SPANCLASSEMOJIEMOJI1F433SPAN', 'MemberCount': 0, 'RemarkName': '🐳老婆', 'NickName': '🐳', 'Sex': 2, 'StarFriend': 0, 'SnsFlag': 49, 'AttrStatus': 105337, 'Alias': '', 'OwnerUin': 0, 'ChatRoomId': 0, 'KeyWord': '', 'City': '', 'IsOwner': 0, 'MemberList': <ContactList: []>, 'RemarkPYInitial': 'SPANCLASSEMOJIEMOJI1F433SPANLP', 'Province': '', 'VerifyFlag': 0, 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=709296501&username=@7a4141ef1c4a06380613134783fa6f29e6a099833b0371c747bdb02939d4966a&skey=@crypt_b1692417_7bcbe32e877bef06be2fe1f3b276ee08'}>, <User: {'DisplayName': '', 'UniFriend': 0, 'RemarkPYQuanPin': '', 'Statues': 0, 'UserName': '@aa9391e46dce0fbdae70a687ed23d3321381ec2083c3e8ff121ef86952fb794b', 'AppAccountFlag': 0, 'Uin': 0, 'HideInputBarFlag': 0, 'Signature': 'Have fun at all costs.', 'EncryChatRoomId': '', 'PYQuanPin': 'Vincent', 'ContactFlag': 3, 'PYInitial': 'VINCENT', 'MemberCount': 0, 'RemarkName': '', 'NickName': 'Vincent', 'Sex': 1, 'StarFriend': 0, 'SnsFlag': 1, 'AttrStatus': 34050309, 'Alias': '', 'OwnerUin': 0, 'ChatRoomId': 0, 'KeyWord': '', 'City': 'Sydney', 'IsOwner': 0, 'MemberList': <ContactList: []>, 'RemarkPYInitial': '', 'Province': 'New South Wales', 'VerifyFlag': 0, 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=709337469&username=@aa9391e46dce0fbdae70a687ed23d3321381ec2083c3e8ff121ef86952fb794b&skey=@crypt_b1692417_7bcbe32e877bef06be2fe1f3b276ee08'}>, <User: {'DisplayName': '', 'UniFriend': 0, 'RemarkPYQuanPin': '', 'Statues': 0, 'UserName': '@c1e67907108d06436d2c5101b3350c18', 'AppAccountFlag': 0, 'Uin': 0, 'HideInputBarFlag': 0, 'Signature': '我就是我，不一样的烟火', 'EncryChatRoomId': '', 'PYQuanPin': 'liangzahefan', 'ContactFlag': 3, 'PYInitial': 'LZHF', 'MemberCount': 0, 'RemarkName': '', 'NickName': '两杂盒饭', 'Sex': 1, 'StarFriend': 0, 'SnsFlag': 49, 'AttrStatus': 105575, 'Alias': '', 'OwnerUin': 0, 'ChatRoomId': 0, 'KeyWord': 'sai', 'City': '长沙', 'IsOwner': 0, 'MemberList': <ContactList: []>, 'RemarkPYInitial': '', 'Province': '湖南', 'VerifyFlag': 0, 'HeadImgUrl': '/cgi-bin/mmwebwx-bin/webwxgeticon?seq=709350368&username=@c1e67907108d06436d2c5101b3350c18&skey=@crypt_b1692417_7bcbe32e877bef06be2fe1f3b276ee08'}>, <User: {'DisplayName': '', 'UniFriend': 0, 'RemarkPYQuanPin': '', 'Statues': 0, 'UserName': '@7aa87a1e1c0812d11366a02a95a72149', 'AppAccountFlag': 0, 'Uin': 0, 'HideInputBarFlag': 0, 'Signature': '', 'EncryChatRoomId': '', 'PYQuanPin': 'Andr', 'ContactFlag': 3, 'PYInitial': 'ANDR', 'MemberCount': 0, 'RemarkName': '', 'NickName': 'André', 'Sex': 1, 'StarFriend': 0, 'SnsFlag': 177, 'AttrStatus': 67602495, 'Alias': '', 'OwnerUin': 0, 'ChatRoomId': 0, 'KeyWord': 'and', 'City': 'Sydney', 'IsOwner': 0, 'MemberList': <ContactList: []>, 'RemarkPYInitial': '', 'Province': 'New ...

# %%
def parse_data(data):
    friends = []
    for item in data[1:]:  # 第一个元素是自己，排除掉
        friend = {
            'NickName': item['NickName'],  # 昵称
            'RemarkName': item['RemarkName'],  # 备注名
            'Sex': item['Sex'],  # 性别：1男，2女，0未设置
            'Province': item['Province'],  # 省份
            'City': item['City'],  # 城市
            'Signature': item['Signature'].replace('\n', ' ').replace(',', ' '),  # 个性签名（处理签名内容换行的情况）
            'StarFriend': item['StarFriend'],  # 星标好友：1是，0否
            'ContactFlag': item['ContactFlag']  # 好友类型及权限：1和3好友，259和33027不让他看我的朋友圈，65539不看他的朋友圈，65795两项设置全禁止
        }
        print(friend)
        friends.append(friend)
    return friends

if __name__ == '__main__':
    print(parse_data(get_data()))
# Out:
# itchat has already logged in.
# {'City': '', 'ContactFlag': 2051, 'StarFriend': 0, 'Province': '', 'RemarkName': '🐳老婆', 'NickName': '🐳', 'Sex': 2, 'Signature': '海蓝时见<span class="emoji emoji1f433"></span>'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Vincent', 'Sex': 1, 'Signature': 'Have fun at all costs.'}
# {'City': '长沙', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '两杂盒饭', 'Sex': 1, 'Signature': '我就是我，不一样的烟火'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'André', 'Sex': 1, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '凡', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '168 Express', 'Sex': 0, 'Signature': '官网：www.168express.com.au'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '周亿良笔庄', 'Sex': 1, 'Signature': '15870035367 小周'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '陈婷', 'Sex': 2, 'Signature': ''}
# {'City': '黄浦', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Cici💋', 'Sex': 2, 'Signature': '我是小曼巴，科蜜！！！'}
# {'City': '南昌', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '肖利锋', 'Sex': 2, 'Signature': '家和u万事兴'}
# {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'kk小小王', 'Sex': 1, 'Signature': '阿弥陀佛！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '媛媛', 'Sex': 2, 'Signature': '工作中不闲聊 按价格直接发红包 见红包发视频 绝对本人'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Gwangju', 'RemarkName': '', 'NickName': '韩乐购&amp;BRAND IS', 'Sex': 2, 'Signature': '韩国贸易公司韩乐购，所有产品韩国直邮，价格优惠，质量保证！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '今日健康澳洲客服', 'Sex': 0, 'Signature': '1.26-2.4春节放假，客服无法正常回复到敬请谅解！'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '高振', 'Sex': 1, 'Signature': '大家新年快乐，鸡年大吉！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '乐乐', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '洲际速递(澳洲)', 'Sex': 1, 'Signature': '人工客服上班时间为:周一至周六北京时间:09:30-17:30'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Kowloon City', 'RemarkName': '', 'NickName': '奔跑的蜗牛', 'Sex': 1, 'Signature': '给人生一个梦，圆梦一个人生'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'ash ériche', 'Sex': 1, 'Signature': '带图问价 没发的并不代表我没有'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Buenos Aires', 'RemarkName': '', 'NickName': '海带', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '\u202d', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Lucas Mayer', 'Sex': 1, 'Signature': 'Hi!'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Angel', 'Sex': 2, 'Signature': '<span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span>'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '夏薇', 'Sex': 2, 'Signature': '激情总在下半场'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '范超然 િ🌝ી', 'Sex': 1, 'Signature': '本屌是个边缘人'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Miss Panda', 'Sex': 0, 'Signature': '贱人就是矫情'}
# {'City': '', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '涛', 'Sex': 1, 'Signature': '十年纺识人，专注户外面料，特别推荐高耐气侯性色牢度户外面料'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '廖总', 'NickName': '阳光雨露leo', 'Sex': 1, 'Signature': '大半年的折腾最终划上句号！'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Corrientes', 'RemarkName': '', 'NickName': '徐弘 Mark', 'Sex': 1, 'Signature': '努力'}
# {'City': '泰安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '泰安 侯', 'Sex': 1, 'Signature': '不用了！！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': ' ', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Paris', 'RemarkName': '', 'NickName': '空白。', 'Sex': 2, 'Signature': '输了你。赢了世界又如何？'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '悉尼时光传媒', 'Sex': 1, 'Signature': '悉尼时光网互助平台'}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Michael Yan', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A.龙门客栈（截单）', 'Sex': 2, 'Signature': 'TEL:0406201818    网站: longmenkezhan.online'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '有病要读书', 'Sex': 0, 'Signature': '本号只用来公众号防失联，不闲聊，抱歉。'}
# {'City': '长沙', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '\uf3ce', 'Sex': 1, 'Signature': '此号已废'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '宇哥', 'Sex': 1, 'Signature': ''}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '张尧', 'Sex': 1, 'Signature': '加油吧'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'AAA🍲2011自助火锅酒楼KTV', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '清粉客服321', 'Sex': 2, 'Signature': ''}
# {'City': '鞍山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '鞍山海虹吊装', 'Sex': 1, 'Signature': '25-350吨吊车以及特种件，大件，小件运输18842086666'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '卡卡', 'Sex': 2, 'Signature': '无名指的爱'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '雷先生', 'NickName': '双车', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小湖南', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A小蜗牛租房平台_悉尼💕', 'Sex': 1, 'Signature': '需要发布房屋信息的同学，请把照片和描述发我。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Lucky_M💓', 'Sex': 2, 'Signature': '所有的遇见都是久别重逢'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Ivy', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Evelyn☀', 'Sex': 2, 'Signature': '不惮人言，不畏世俗，不弃自我，如此甚好。'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '梁国平', 'NickName': '进贤梁国平', 'Sex': 1, 'Signature': '做人要正、以诚相待！'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Marx', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Roy', 'Sex': 1, 'Signature': 'Valar morghulis. Valar dohaeris.'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'wenfei @ 贇', 'Sex': 1, 'Signature': 'Go'}
# {'City': 'Melbourne', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'A墨尔本互助社区', 'Sex': 2, 'Signature': '广告无处发？我来帮你免费推广'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'uber学校 0426917353', 'Sex': 2, 'Signature': '靠谱Uber新司机专业指导，时薪30-60刀。Code: d37ftuqbue'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'DaviDuan', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A.康康🇦🇺丶 ପଓ*ೃ࿐🚚', 'Sex': 2, 'Signature': '澳！洲！直！邮！'}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '孙悟饭 没及时回复加（Ljj5362）', 'Sex': 1, 'Signature': 'Alsis      主理人'}
# {'City': '青岛', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': 'dodo', 'Sex': 1, 'Signature': '一腔孤勇'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '望舒', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '中医推拿', 'Sex': 2, 'Signature': '帝王亨受每天不同的美女为你放松按摩推油踩背'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Cici（massage shop)', 'Sex': 2, 'Signature': '110A Victoria Road Drummoyne'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '澳中VINCENT牛肉', 'NickName': '澳中VINCENT', 'Sex': 1, 'Signature': 'Vincent（04169 19992）'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小妖 （换号了 加tuhaoxiaoniu）', 'Sex': 2, 'Signature': '换号了 tuhaoxiaoniu'}
# {'City': '大连', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': 'chen', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Alex', 'Sex': 1, 'Signature': "What doesn't kill you make you stronger"}
# {'City': '昆明', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': 'H', 'Sex': 1, 'Signature': '人生该走的弯路，其实一米也少不了！'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'hohoho', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '王可学姐', 'NickName': '王可', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'MMD Health客服', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '喵星人的烦恼', 'Sex': 2, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '淡定', 'Sex': 1, 'Signature': ''}
# {'City': '河北', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '葉森', 'Sex': 1, 'Signature': '善事善行'}
# {'City': '遵义', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '贵州', 'RemarkName': '', 'NickName': '酷乐', 'Sex': 1, 'Signature': ''}
# {'City': '台北市', 'ContactFlag': 8199, 'StarFriend': 0, 'Province': '台湾', 'RemarkName': '樊帆', 'NickName': '睡过头', 'Sex': 1, 'Signature': '昨天'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Viki奇', 'Sex': 2, 'Signature': '看得惯，走得出！ 看得惯他人的不是； 走得出自己的负能量！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Olbia-Tempio', 'RemarkName': '减50下次', 'NickName': '🔱俊哥哥 Ju', 'Sex': 1, 'Signature': '朋友圈一系列物品可验货， 接nike官网7折！'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '初', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'A02【开心】聊天专用', 'Sex': 2, 'Signature': '副微信长时间不回复请联系24小时服务热线：17701629061【开心】'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '杨安琪', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Michael Zou', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '薯条妹妹', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '-', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'X', 'Sex': 1, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '刘梅', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '任我行', 'Sex': 1, 'Signature': '欲穷千里目 更上一层楼'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '青年', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '87号', 'Sex': 1, 'Signature': 'easy'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Newstars移民顾问Jessie🎉', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'UGG630', 'Sex': 0, 'Signature': 'Shop 3   630 George st   Sydney 2000'}
# {'City': '金华', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '😈😈😈cyh', 'Sex': 1, 'Signature': '！'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '王芳', 'Sex': 2, 'Signature': '面朝大海，春暖花开'}
# {'City': '闸北', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Jamie', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '.', 'Sex': 1, 'Signature': '因为简单 所以自在'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '彼岸的星空', 'Sex': 1, 'Signature': '“那理想的彼岸也许不存在，我依然会走在那旅途上。”'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Summer', 'Sex': 1, 'Signature': '                   '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'St. Anthony', 'RemarkName': '订机票', 'NickName': '🌛lance', 'Sex': 2, 'Signature': '我有两小时的break'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': "' zZ", 'Sex': 1, 'Signature': '429918'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '我卖海参贼便宜', 'Sex': 1, 'Signature': '773'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'A-Jimmy', 'Sex': 1, 'Signature': '“人类的悲欢并不相通，我只觉得他们吵闹”'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': 'Feni', 'Sex': 1, 'Signature': ''}
# {'City': '南京', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '「Mr. Fu」', 'Sex': 1, 'Signature': ''}
# {'City': '海淀', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '粱荣', 'NickName': '梁荣', 'Sex': 1, 'Signature': '~'}
# {'City': '', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '暖阳(☆_☆)', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jeffrey', 'Sex': 1, 'Signature': ''}
# {'City': '扬州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'Tony', 'Sex': 1, 'Signature': '永远不要让看好你的人失望'}
# {'City': '池州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '高飞', 'Sex': 1, 'Signature': '厚德载物。一日真，二日忍'}
# {'City': '闵行', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'summer', 'Sex': 2, 'Signature': ''}
# {'City': '泰州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'John Zhang | 张俊松', 'Sex': 1, 'Signature': '高级地产置业投资顾问，真心待人，真诚做事！'}
# {'City': '深圳', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'MI', 'Sex': 1, 'Signature': ''}
# {'City': '惠州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Holly', 'Sex': 1, 'Signature': '只出正品鞋，需要什么鞋什么配色问我。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '畅灵 · 悉尼客服2号', 'Sex': 0, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'April.huang(^^)', 'Sex': 2, 'Signature': '祈祷全家都健康幸福！'}
# {'City': '合肥', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '张贺', 'Sex': 1, 'Signature': '我不入地狱 谁入地狱'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Tokyo', 'RemarkName': '', 'NickName': 'Ink私人顶级订制', 'Sex': 0, 'Signature': '主营chanel私人订制 一件起订 正品主号inkerzhang '}
# {'City': '海淀', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '启齐', 'Sex': 1, 'Signature': 'Actions speak louder than words'}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'Infinity傲娇班主任-Carina', 'Sex': 2, 'Signature': '做职业培训，我们是认真的！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '바보', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '唐🐝', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Alven', 'Sex': 1, 'Signature': '新年三大目标'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '大毛儿大毛儿大毛儿\U0001f988', 'Sex': 1, 'Signature': '想招大胸妹 想买大衣柜'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Lemon🍋', 'Sex': 2, 'Signature': '微信不要让我失望啊〜'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '夏天的雨熊玉林', 'Sex': 2, 'Signature': '人生最曼妙的风景，是内心的淡定与从容'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '多俪服装', 'Sex': 2, 'Signature': '欧美原单时装新款'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '时栗然', 'NickName': '西米', 'Sex': 2, 'Signature': '不要因为岁月静好而荒废了认知升级'}
# {'City': 'Toronto', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Ontario', 'RemarkName': '', 'NickName': 'Easyship-Chinese', 'Sex': 1, 'Signature': '专业中国转运全球'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '李红新', 'Sex': 1, 'Signature': 'test'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '富富', 'Sex': 1, 'Signature': '生活就是问题叠着问题'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '卖货的冰冰', 'Sex': 0, 'Signature': '能力范围内鉴定 中意巴黎世家吧务组 春节期间正常发货'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '曾顺琪(雪狐)', 'Sex': 1, 'Signature': ''}
# {'City': '桂林', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广西', 'RemarkName': '', 'NickName': '听着肖邦吃泡面', 'Sex': 1, 'Signature': '眼底星空、'}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'moo', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '精时翻译Evan', 'Sex': 1, 'Signature': '一家专业靠谱的翻译公司'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '南派翻译', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A安康澳洲直邮批发代购 招代理！', 'Sex': 2, 'Signature': '专业澳洲直邮代购批发 欢迎咨询 招代理！ 奶粉保健品化妆品零食'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'VICKY🔆LEE', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '贷款 kevin', 'NickName': 'Keven', 'Sex': 1, 'Signature': '房贷，车贷，商业贷款，个人贷款'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '東', 'Sex': 1, 'Signature': ''}
# {'City': '济宁', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '张志鸿', 'Sex': 1, 'Signature': 'sedimentation！'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '\u3000', 'Sex': 1, 'Signature': 'L’Aveugle par Amour♫'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '孔利明', 'NickName': 'klm', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '佟.', 'Sex': 1, 'Signature': ' '}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jingyi', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Frankfurt', 'RemarkName': '', 'NickName': '随缘自适', 'Sex': 1, 'Signature': '福往者福来 爱出者爱返'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '郭璇', 'Sex': 2, 'Signature': '愿你自己有充分的忍耐去担当， 有充分单纯的心去信仰。'}
# {'City': '和平', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '猪小仙', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'YoYo', 'Sex': 2, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '杨波', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '何文清', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Matt张启凡', 'Sex': 1, 'Signature': 'Good things take time 🐌'}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '马珍平', 'NickName': '姆9s姥马', 'Sex': 2, 'Signature': ''}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'air up there', 'Sex': 1, 'Signature': '还我真实。'}
# {'City': '雅安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'will', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '九州搬运 and 东北情熏酱炒菜馆', 'Sex': 1, 'Signature': '打工--生意--事业  是人生的三个不同选择阶段。'}
# {'City': 'New York City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'jeremmy💭', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '媚姐', 'Sex': 0, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '街头杀猪的', 'Sex': 1, 'Signature': ''}
# {'City': '鸡西', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': '其实星空是为你点亮的', 'Sex': 1, 'Signature': '邂逅你，是生生世世的约定。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '收费咯', 'Sex': 1, 'Signature': '收费不点号'}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Dream.girls', 'Sex': 2, 'Signature': '尽善尽美<span class="emoji emoji2764"></span>️'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '马志永13698003761', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 7, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '康芦钧', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': "'  Yw", 'Sex': 1, 'Signature': ' 一花一世界'}
# {'City': '佛山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '烽子', 'Sex': 1, 'Signature': '电信号码18128788880或联通号码18566030201'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '哭泣的卫生纸', 'Sex': 1, 'Signature': '只卖身，不卖艺〜'}
# {'City': '', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨姥姥', 'Sex': 0, 'Signature': ''}
# {'City': '大兴', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'A0任健,我善治腰，创旗，任医堂', 'Sex': 1, 'Signature': ''}
# {'City': '湘西', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Y', 'Sex': 1, 'Signature': '   只有拼'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '萌博士生活服务平台ʚ2ɞ', 'Sex': 1, 'Signature': '萌博士将随时解决你的需求'}
# {'City': '哈尔滨', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': 'Owen、🌟 张', 'Sex': 1, 'Signature': '<span class="emoji emoji1f3e0"></span>Noble Group| 诺达投资顾问|🏓️| 四月<span class="emoji emoji1f308"></span>'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '肉小美', 'Sex': 2, 'Signature': '我是肉肉哇~~我是菓菓妈'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '下雨天', 'Sex': 2, 'Signature': 'Be the best version of you'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '远山', 'Sex': 1, 'Signature': '没写完  等会'}
# {'City': '咸宁', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Bucky', 'Sex': 1, 'Signature': ''}
# {'City': '咸宁', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Wan', 'Sex': 1, 'Signature': 'kept hoping'}
# {'City': '湖州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '陳Tyang', 'Sex': 1, 'Signature': '佛系卖家看上问价'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Evan', 'Sex': 1, 'Signature': ''}
# {'City': '烟台', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '王伟好极了🐑🐏🐐', 'Sex': 1, 'Signature': '我就要naive'}
# {'City': '成都', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '李然至', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '晓', 'Sex': 2, 'Signature': '手机关机是因为没电啦！'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Verve', 'Sex': 1, 'Signature': 'Veni vidi vici '}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '毅🔝', 'Sex': 1, 'Signature': ''}
# {'City': '唐山', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '', 'NickName': 'linkin park ', 'Sex': 1, 'Signature': '_<span class="emoji emojiae"></span>_<span class="emoji emojiae"></span>'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Abu Dhabi', 'RemarkName': '', 'NickName': '.  love    MQ', 'Sex': 1, 'Signature': '本无意与众不同、<span class="emoji emoji1f6ac"></span>。怎耐何品味出众……'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨子秋', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Fanny Chen', 'Sex': 2, 'Signature': '有人先走有人留，没有人陪我到最后'}
# {'City': '杭州', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Leif.Yu', 'Sex': 1, 'Signature': ''}
# {'City': '沈阳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': 'Beyond', 'Sex': 1, 'Signature': '人在江湖，身不由己。'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'London', 'RemarkName': '新裤子XL', 'NickName': '小琦™', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jasons Pharmacy Supplies', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Alfonso', 'Sex': 1, 'Signature': ''}
# {'City': '哈尔滨', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': '😄 傲然', 'Sex': 1, 'Signature': '面对未知的世界，你需要的只是好奇心'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'D', 'Sex': 1, 'Signature': 'why so serious？'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '王王山而', 'Sex': 1, 'Signature': '不过是花瓣 微不足道'}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'L', 'Sex': 1, 'Signature': ' '}
# {'City': '河西', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '赵舒豪', 'Sex': 1, 'Signature': 'Vita Dolce. '}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '我想我是海', 'Sex': 1, 'Signature': '天若有情天亦老'}
# {'City': '虹口', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '我全要', 'Sex': 1, 'Signature': '我全要'}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '风风火火', 'Sex': 2, 'Signature': '亲们，请保存我最新手机号18109293228...原号码即将停用。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '王佐', 'NickName': 'W', 'Sex': 1, 'Signature': 'models &amp; bottles'}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Superlit', 'Sex': 1, 'Signature': ''}
# {'City': '福州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '海天一', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': '🐻 哦哦哦', 'Sex': 1, 'Signature': '可能还会再遇见一个你'}
# {'City': '成都', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Tough girl 娟 🐯', 'Sex': 2, 'Signature': '做人，简单就好。生活，宁静就好。'}
# {'City': '岳阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '张凯西', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '向日葵', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨帆', 'Sex': 1, 'Signature': ''}
# {'City': '南京', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '玲玲', 'Sex': 2, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Albus🔮', 'Sex': 1, 'Signature': '为曾经的梦想也努力一回。'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '不可一世k', 'Sex': 1, 'Signature': '换汇找我'}
# {'City': '合肥', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '🍁', 'Sex': 1, 'Signature': '哩哩哩哩哩哩哩哩哩lll'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Amber澳洲代购', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Tina Wu', 'Sex': 2, 'Signature': 'Looking for like-minded friends '}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'BingBing🎶👣', 'Sex': 2, 'Signature': '一生再也不敢那么勇敢，为你！'}
# {'City': '绍兴', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'adǎ', 'Sex': 1, 'Signature': ''}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '辉', 'Sex': 1, 'Signature': '尚和合，求大同，一切行止由心。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Fukuoka', 'RemarkName': '', 'NickName': 'kin', 'Sex': 1, 'Signature': "We're the nobodies. Wanna be somebodies "}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Yue', 'Sex': 2, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '尚贤', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '张梦婷', 'NickName': '7-11💓', 'Sex': 2, 'Signature': '包子脸，豆腐心！'}
# {'City': '文山', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': 'Leon Zhu', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Studyz', 'Sex': 1, 'Signature': 'Videomaker'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '宋卫', 'Sex': 1, 'Signature': '真情是一生永远不变的主题!爱是我们永恒不变的神话！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '一一一一一一一一', 'Sex': 1, 'Signature': '          祈禱未來！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '努力奋斗', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '嘿～请叫我余先生＂', 'Sex': 1, 'Signature': '躲得过对酒当歌的夜，躲不过四下无人的街……'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '大头爸爸爸爸爸爸爸爸爸爸', 'Sex': 1, 'Signature': '                                                     CMS<span class="emoji emoji2764"></span>️'}
# {'City': '苏州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'leoking', 'Sex': 1, 'Signature': 'Forza Milan！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'juice', 'Sex': 1, 'Signature': '怒马鲜衣。'}
# {'City': '广州', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'PK', 'Sex': 1, 'Signature': '你那么尊贵，怎么不要个王位'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Hamburg', 'RemarkName': '', 'NickName': '😊🇩🇪珊珊王', 'Sex': 2, 'Signature': '不忘初心。'}
# {'City': 'New York City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'UNIELITE 直发需求至签名电邮', 'Sex': 1, 'Signature': '如不在 请直发需求至 unieliteworks@hotmail.com'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Merrick', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'MATTHEW', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '蓉', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Daric', 'Sex': 1, 'Signature': ' '}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '董某', 'Sex': 1, 'Signature': ''}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': '阿汪', 'Sex': 1, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '毛线！', 'Sex': 1, 'Signature': '感谢相遇'}
# {'City': '徐汇', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '不愿透露姓名的赵伟先生', 'Sex': 1, 'Signature': '准会想起父亲带他去参观冰块的那个遥远的下午。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Au. 夏因🏅Dian鋪 ®', 'Sex': 1, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '👑 谢婷🌛 🎵', 'Sex': 2, 'Signature': 'To fast to live To young to die'}
# {'City': '渝北', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '重庆', 'RemarkName': '', 'NickName': '（kol）', 'Sex': 1, 'Signature': ''}
# {'City': '廊坊', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '', 'NickName': 'Sunny Bernabeu', 'Sex': 1, 'Signature': 'Mont-Joie！Charge！Ура！'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '东东', 'Sex': 1, 'Signature': '出发，向着远方'}
# {'City': '西安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': 'Ding', 'Sex': 1, 'Signature': ''}
# {'City': '黄浦', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Clark', 'Sex': 1, 'Signature': ''}
# {'City': '海淀', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '晓晓', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '丁小雪', 'Sex': 2, 'Signature': '生命不息，折腾不止~ <span class="emoji emoji1f4aa"></span>'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Wang', 'Sex': 1, 'Signature': ''}
# {'City': 'Portland City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Oregon', 'RemarkName': '', 'NickName': 'The lamb of GOD$', 'Sex': 1, 'Signature': 'Fate for what？'}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': '🙈🙉🙊', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杰瑞', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Auckland', 'RemarkName': '', 'NickName': '蔡懿', 'Sex': 1, 'Signature': '《Catch Me If You Can》I Am The Second Mouse ！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'EGO', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'Jake Hu', 'Sex': 1, 'Signature': 'conservatory，aurora，swanston central指定出租管理中介'}
# {'City': '淄博', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '阿威', 'Sex': 1, 'Signature': '。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': 'IGA 奶粉', 'NickName': '萬劫', 'Sex': 1, 'Signature': '佛说：十方世界，众生平等，我说：八荒六合，唯我独尊。'}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '🔱VIP专属服务™Vivian', 'Sex': 2, 'Signature': '<span class="emoji emoji1f493"></span><span class="emoji emoji1f493"></span>微信没回，直接谈语音'}
# {'City': '湖州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '老徐👣', 'NickName': '唐唐', 'Sex': 2, 'Signature': '享受人生'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '广告号两只考拉🐨 澳品直邮', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A🍉🍓嘎嘎', 'Sex': 2, 'Signature': '晚上11点半后自助下单哦~'}
# {'City': '泉州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': 'peng  😂 Te【国潮代发】', 'Sex': 1, 'Signature': '老牌微商，国潮、美潮、奢潮，支持代发'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Eric', 'Sex': 1, 'Signature': ''}
# {'City': '苏州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '葛桂月', 'Sex': 2, 'Signature': '有时无牵无挂不是挺好？'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山西', 'RemarkName': '', 'NickName': '橘子', 'Sex': 2, 'Signature': '岂能尽如人意'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '三商', 'Sex': 1, 'Signature': '三商客服在线时间:  周一至周五 悉尼时间 11am - 5pm'}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '杨哥  (', 'Sex': 1, 'Signature': '全网爆款 实力供货'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Laffa Girl悉尼', 'Sex': 2, 'Signature': '<span class="emoji emoji1f4de"></span> ：+61452139950  网站：www.laffagirl.live'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '优品-营销号（广告号）', 'Sex': 0, 'Signature': '广告号-不回答问题与接单<span class="emoji emoji1f64f"></span>'}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '小把戏', 'Sex': 1, 'Signature': '平平安安就好'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Struggle', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'BASEBONE', 'Sex': 2, 'Signature': '□'}
# {'City': '温州', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '阿芳（创新吸塑包装）', 'Sex': 1, 'Signature': '有目标人生才有意义！吸塑包装有需要的找我！'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '皇冠店搜aramer加新号ARAMER7', 'Sex': 0, 'Signature': 'tb搜店铺：aramer'}
# {'City': '青岛', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': 'ADIDAS NIKE批发一件代发招代理', 'Sex': 1, 'Signature': '专注原单，专注高品质'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Alstonzzzzzzzzz', 'Sex': 0, 'Signature': '鞋子aj yeezy 喷泡 等 衣服 sup palace 等，接nike官网7.5折代购'}
# {'City': '张家界', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Eat—Yourself  ', 'Sex': 1, 'Signature': '-没有退路的灵魂才会呐喊出声'}
# {'City': 'Sydney', 'ContactFlag': 73729, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '谢小妞狠纠结澳洲代购', 'Sex': 2, 'Signature': '设计师品牌集合平台 顺丰到付'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Kai澳洲代购', 'Sex': 1, 'Signature': ''}
# {'City': '厦门', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '悟小空', 'Sex': 2, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '上海（双喜）全国接单号', 'Sex': 1, 'Signature': '进门报双喜^，预约电话:18321668078'}
# {'City': '南开', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '烙✿印', 'Sex': 1, 'Signature': '毫不犹豫，绝不退缩。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '对的啊', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Dubayy', 'RemarkName': '', 'NickName': '陈振宇', 'Sex': 1, 'Signature': ''}
# {'City': '南充', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '噘噘嘴（无扰清粉）', 'Sex': 2, 'Signature': '如果这个号无人回复，请加 juejuezui666'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '鞋世界', 'Sex': 2, 'Signature': '宠爱天使奢侈品'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '李晔', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'MD Ranking面岛爱购', 'Sex': 0, 'Signature': '澳洲最全最划算的日韩美妆店<span class="emoji emoji2764"></span>️周1-7营业时间11am-10pm'}
# {'City': 'Toronto', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'Ontario', 'RemarkName': '', 'NickName': '顾大师下单号', 'Sex': 1, 'Signature': '只做好货 屏蔽不加 默认顺丰到付 '}
# {'City': '郑州', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '河南', 'RemarkName': '', 'NickName': 'ivy', 'Sex': 2, 'Signature': ''}
# {'City': '惠州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '坚坚', 'Sex': 1, 'Signature': '心有所戒，心有所仰，心有所获！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '甜★甜♂', 'Sex': 2, 'Signature': '没有公主的命，但有一颗女王的心！'}
# {'City': '湾仔区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '香港', 'RemarkName': '', 'NickName': '段小旺', 'Sex': 1, 'Signature': '弓长双木'}
# {'City': '阜新', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '叶堃.', 'Sex': 1, 'Signature': ''}
# {'City': '宝山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'SkyHoke', 'Sex': 1, 'Signature': ''}
# {'City': '闵行', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '大寒', 'Sex': 1, 'Signature': ''}
# {'City': '海口', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '海南', 'RemarkName': '鼻炎小犀牛', 'NickName': 'Devil', 'Sex': 1, 'Signature': 'Baby you light up my world like nobody else'}
# {'City': '成都', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '困兽之斗', 'Sex': 1, 'Signature': '有朝一日龙得水，我让长江水倒流'}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '群', 'NickName': '珷玞', 'Sex': 1, 'Signature': '故事从何说起'}
# {'City': '常州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '陈禹啸', 'Sex': 1, 'Signature': ''}
# {'City': '琼海', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '海南', 'RemarkName': '', 'NickName': '咦', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Edgar', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '大熊', 'NickName': '熊俊', 'Sex': 1, 'Signature': 'unɾ ɓuoıx'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '梦云', 'Sex': 2, 'Signature': ''}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Simon', 'Sex': 1, 'Signature': '许你十里桃花任你大浪狂沙'}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '路洁', 'Sex': 2, 'Signature': '该吃吃该喝喝，该玩玩该乐乐，破事别往心里搁'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '发型师', 'NickName': '蓝调@Eric', 'Sex': 1, 'Signature': '心灵的沉淀需要真实的经历去完成，继续走继续失去'}
# {'City': '常州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'Treasure❇', 'Sex': 1, 'Signature': '找乐趣'}
# {'City': 'Vancouver', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'British Columbia', 'RemarkName': '', 'NickName': '小熊猫🐼', 'Sex': 2, 'Signature': '只做最好的卖家！品质保证！招代理 一件代发！'}
# {'City': '深圳', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '韩昊育😳', 'Sex': 1, 'Signature': '我没有任何其他微信号，谨防假冒'}
# {'City': '长沙', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Joe-Jo', 'Sex': 1, 'Signature': 'I’m afraid I haven’t been alive enough. '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '陶然亭人', 'Sex': 1, 'Signature': 'climber'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '亨利', 'NickName': '专修宝马奔驰亨利', 'Sex': 1, 'Signature': '诚信用心做车710 Pennant hills road carlingford'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '陶陶', 'Sex': 1, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '小白兔。', 'Sex': 2, 'Signature': '                哦'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'M', 'Sex': 1, 'Signature': 'Phil-'}
# ...
# {'City': 'Sydney', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '😍JessicaYu😍', 'Sex': 2, 'Signature': '销售，绝不是降低身份去取悦客户，而是像朋友一样给予合理的建议'}
# {'City': '', 'ContactFlag': 73731, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '🐋', 'Sex': 2, 'Signature': '生人勿近               .'}
# {'City': '昆明', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': '咸鱼', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Benevolence.', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '.cccb.', 'Sex': 1, 'Signature': ' 做个好人。'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '没没没道理', 'Sex': 1, 'Signature': '最初的梦 谁都想笑着做完'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '我走路带风', 'Sex': 1, 'Signature': '#                       你相信来日方长吗?                  '}
# {'City': '南京', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '西瓜皮太郎', 'Sex': 1, 'Signature': ''}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '劉', 'Sex': 2, 'Signature': '你若爱，生活哪里都可爱'}
# {'City': '宝山', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '丰丰.', 'Sex': 1, 'Signature': ''}
# {'City': '绍兴', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Pan。W✨', 'Sex': 1, 'Signature': '万年太久，只争朝夕'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Danny', 'Sex': 1, 'Signature': '不知疲倦'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Anti', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '贰0壹久', 'Sex': 2, 'Signature': '平安喜乐'}
# {'City': '石家庄', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '衣服T', 'NickName': 'yahooooo', 'Sex': 1, 'Signature': '                                  年轻的心 热泪盈眶'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Steven:)', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Sherly GBI联合创始人&amp; R+F', 'Sex': 2, 'Signature': '微信太久没回请打电话!'}
# {'City': '朝阳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'Lucifer.柴', 'Sex': 1, 'Signature': '无心'}
# {'City': 'Miyazaki-shi', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'Miyazaki-ken', 'RemarkName': '', 'NickName': '-平凡', 'Sex': 1, 'Signature': '学会把“自己”藏起来'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '哈嘿', 'NickName': '🌤', 'Sex': 1, 'Signature': ''}
# {'City': '南通', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'lo2', 'Sex': 1, 'Signature': 'hugerab@qq.com'}
# {'City': '深圳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'ZHENGX', 'Sex': 1, 'Signature': '╳Too Much Sauce╳'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '宁婷', 'Sex': 2, 'Signature': ''}
# {'City': '深圳', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Dciken', 'Sex': 1, 'Signature': 'Your emptiness and your sickening soul'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'ubee', 'Sex': 1, 'Signature': '独立自由与人为善'}
# {'City': '台州', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'francis zfb扫码', 'Sex': 1, 'Signature': '人一直在 有事私聊'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Dublin', 'RemarkName': '', 'NickName': 'Hepburn', 'Sex': 1, 'Signature': '＂这个季节很干净＂'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '雷克雅未克儿', 'Sex': 1, 'Signature': '已事过境迁'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Jūne', 'Sex': 1, 'Signature': '     游龙当归海'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '萌', 'Sex': 2, 'Signature': '甜甜圈🍩'}
# {'City': '深圳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '白白白', 'Sex': 1, 'Signature': '随遇而安'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '十二', 'Sex': 1, 'Signature': '很忙 别烦'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '💜', 'RemarkName': '', 'NickName': 'ᴘᴇᴀᴄʜ ᴊᴀᴍ', 'Sex': 2, 'Signature': ' ☃︎'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Deom 1', 'Sex': 1, 'Signature': 'Following \\ 2020'}
# {'City': '韶关', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '卖家', 'NickName': 'Alexxx_x', 'Sex': 1, 'Signature': '學會在冷靜中瘋狂提速  \\  『 ᴄɴʀɪsᴇ. 」 '}
# {'City': '沈阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '长大', 'Sex': 2, 'Signature': ''}
# {'City': 'Port Augusta', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'South Australia', 'RemarkName': '', 'NickName': '不易', 'Sex': 1, 'Signature': '3915.8'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '糖小糖', 'Sex': 2, 'Signature': '願妳熬得過深夜痛哭 天亮依然鏗鏘如故'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Siwei | 思危 🔰', 'Sex': 1, 'Signature': '不积跬步，无以至千里'}
# {'City': '杭州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '别样de', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'ASH1a.Ashfield.凤雅堂', 'Sex': 2, 'Signature': '澳洲厂家品牌代理商，专业美妆顾问，一件无痕代发，可支付宝微信'}
# {'City': 'New York', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'ㅤ', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '亻', 'Sex': 2, 'Signature': '孤岛'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'AuchoiceWL😊（Healthyline接单', 'Sex': 1, 'Signature': 'waterlooHealthyLine直邮中国 营业时间（国内08:00-17:00）'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '曹丽', 'Sex': 2, 'Signature': '美梦成真'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A🏊游泳健身-阿磊🍭', 'Sex': 1, 'Signature': '  R  1   3   5  ┗╋╋┫   2  4  6'}
# {'City': '海淀', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '邓kai', 'Sex': 1, 'Signature': '不诚信不加、爱装B不加、无意图不加、不爱数据不加'}
# {'City': '广州', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '叶子', 'Sex': 1, 'Signature': '用仅有的青春赌明天'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '黄神仙', 'Sex': 1, 'Signature': 'hwjyz000602'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'San', 'Sex': 1, 'Signature': '3301'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A💓sun', 'Sex': 2, 'Signature': '憋疯啦！！！'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '澳有鞋子总客服', 'Sex': 2, 'Signature': '在线时间 8:00-11:30  12:30-5:00'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Seoul', 'RemarkName': '', 'NickName': 'Taeko-🌗', 'Sex': 1, 'Signature': '学到的要教人 赚到的要给人'}
# {'City': '九龙城区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '香港', 'RemarkName': '', 'NickName': 'Auzggg', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小方', 'Sex': 1, 'Signature': 'To be a batter man'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'z', 'Sex': 1, 'Signature': ''}
# {'City': '沈阳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '肉肉', 'Sex': 1, 'Signature': ''}
# {'City': '湖州', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': 'Kaiwa UK9', 'NickName': '我最爱的男人', 'Sex': 1, 'Signature': '     '}
# {'City': 'Wilmington City', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'North Carolina', 'RemarkName': '', 'NickName': 'Jeremy Li', 'Sex': 1, 'Signature': '克己 慎独'}
# {'City': '合肥', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': 'Polaris', 'Sex': 2, 'Signature': '做一个情绪稳定的成年人'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Kyoto', 'RemarkName': '', 'NickName': '🌈Levi Tan', 'Sex': 1, 'Signature': 'Universe '}
# {'City': '合肥', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '赵豪', 'Sex': 1, 'Signature': 'NOMAD '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小虎鯨胡八一 ฅ*ↀωↀ*ฅ', 'Sex': 2, 'Signature': '『請伱收起一切相信這晚只是一場遊戲一場夢。』'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'DankeYjm', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Vienna', 'RemarkName': '', 'NickName': '小陈', 'Sex': 2, 'Signature': '结婚不等于幸福，单身也不意味着不幸！因为我们出生就一个人！'}
# {'City': '海淀', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '操', 'NickName': '鲁 大 少', 'Sex': 1, 'Signature': 'Heartless.'}
# {'City': '厦门', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '猪小悦', 'Sex': 2, 'Signature': '人生在世  及时行乐tough times do not last tough people do'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Zero -Two', 'Sex': 1, 'Signature': '只要最后是你，就好。'}
# {'City': '南昌', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '杨廷弼（不公子）', 'Sex': 1, 'Signature': 'u are my sunshine'}
# {'City': '西安', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '张小宝', 'Sex': 2, 'Signature': ''}
# {'City': '潮州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'JJ', 'Sex': 1, 'Signature': 'sj'}
# {'City': 'Sydney', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Whitney-銀行房貸經理℡', 'Sex': 2, 'Signature': 'nab Home Lending Manager国民銀行貸款經理0405626881'}
# {'City': '杭州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '隺鸟隺鸟子', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '🌟Gensin（支持花呗）', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小智荣', 'Sex': 1, 'Signature': '爱腻嘉真是太好了'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Sun jack (Snap Fitness trainer )', 'Sex': 1, 'Signature': 'Nothing can pull me back'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': 'UK10 L M', 'NickName': 'William', 'Sex': 1, 'Signature': 'I will be nicer if you be smarter.'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'vv', 'Sex': 1, 'Signature': '把兴趣上升到态度'}
# {'City': '九江', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': "C'est la vie", 'Sex': 2, 'Signature': '坚持努力，该来的都在路上。'}
# [{'City': '', 'ContactFlag': 2051, 'StarFriend': 0, 'Province': '', 'RemarkName': '🐳老婆', 'NickName': '🐳', 'Sex': 2, 'Signature': '海蓝时见<span class="emoji emoji1f433"></span>'}, {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Vincent', 'Sex': 1, 'Signature': 'Have fun at all costs.'}, {'City': '长沙', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '两杂盒饭', 'Sex': 1, 'Signature': '我就是我，不一样的烟火'}, {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'André', 'Sex': 1, 'Signature': ''}, {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '凡', 'Sex': 1, 'Signature': ''}, {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '168 Express', 'Sex': 0, 'Signature': '官网：www.168express.com.au'}, {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '周亿良笔庄', 'Sex': 1, 'Signature': '15870035367 小周'}, {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '陈婷', 'Sex': 2, 'Signature': ''}, {'City': '黄浦', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Cici💋', 'Sex': 2, 'Signature': '我是小曼巴，科蜜！！！'}, {'City': '南昌', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '肖利锋', 'Sex': 2, 'Signature': '家和u万事兴'}, {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'kk小小王', 'Sex': 1, 'Signature': '阿弥陀佛！'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '媛媛', 'Sex': 2, 'Signature': '工作中不闲聊 按价格直接发红包 见红包发视频 绝对本人'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Gwangju', 'RemarkName': '', 'NickName': '韩乐购&amp;BRAND IS', 'Sex': 2, 'Signature': '韩国贸易公司韩乐购，所有产品韩国直邮，价格优惠，质量保证！'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '今日健康澳洲客服', 'Sex': 0, 'Signature': '1.26-2.4春节放假，客服无法正常回复到敬请谅解！'}, {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '高振', 'Sex': 1, 'Signature': '大家新年快乐，鸡年大吉！'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '乐乐', 'Sex': 2, 'Signature': ''}, {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '洲际速递(澳洲)', 'Sex': 1, 'Signature': '人工客服上班时间为:周一至周六北京时间:09:30-17:30'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Kowloon City', 'RemarkName': '', 'NickName': '奔跑的蜗牛', 'Sex': 1, 'Signature': '给人生一个梦，圆梦一个人生'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'ash ériche', 'Sex': 1, 'Signature': '带图问价 没发的并不代表我没有'}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Buenos Aires', 'RemarkName': '', 'NickName': '海带', 'Sex': 1, 'Signature': ''}, {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '\u202d', 'Sex': 0, 'Signature': ''}, {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Lucas Mayer', 'Sex': 1, 'Signature': 'Hi!'}, {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Angel', 'Sex': 2, 'Signature': '<span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span>'}, {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '夏薇', 'Sex': 2, 'Signature': '激情总在下半场'}, {'City': '', 'ContactFlag': 8195, 'StarFr ...

# %%
def save_to_txt():
    friends = parse_data(get_data())
    for item in friends:
        with open('friends.txt', mode='a', encoding='utf-8') as f:
            f.write('%s,%s,%d,%s,%s,%s,%d,%d\n' % (
                item['NickName'], item['RemarkName'], item['Sex'], item['Province'], item['City'], item['Signature'],
                item['StarFriend'], item['ContactFlag']))

if __name__ == '__main__':
    save_to_txt()
# Out:
# itchat has already logged in.
# {'City': '', 'ContactFlag': 2051, 'StarFriend': 0, 'Province': '', 'RemarkName': '🐳老婆', 'NickName': '🐳', 'Sex': 2, 'Signature': '海蓝时见<span class="emoji emoji1f433"></span>'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Vincent', 'Sex': 1, 'Signature': 'Have fun at all costs.'}
# {'City': '长沙', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '两杂盒饭', 'Sex': 1, 'Signature': '我就是我，不一样的烟火'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'André', 'Sex': 1, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '凡', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '168 Express', 'Sex': 0, 'Signature': '官网：www.168express.com.au'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '周亿良笔庄', 'Sex': 1, 'Signature': '15870035367 小周'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '陈婷', 'Sex': 2, 'Signature': ''}
# {'City': '黄浦', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Cici💋', 'Sex': 2, 'Signature': '我是小曼巴，科蜜！！！'}
# {'City': '南昌', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '肖利锋', 'Sex': 2, 'Signature': '家和u万事兴'}
# {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'kk小小王', 'Sex': 1, 'Signature': '阿弥陀佛！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '媛媛', 'Sex': 2, 'Signature': '工作中不闲聊 按价格直接发红包 见红包发视频 绝对本人'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Gwangju', 'RemarkName': '', 'NickName': '韩乐购&amp;BRAND IS', 'Sex': 2, 'Signature': '韩国贸易公司韩乐购，所有产品韩国直邮，价格优惠，质量保证！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '今日健康澳洲客服', 'Sex': 0, 'Signature': '1.26-2.4春节放假，客服无法正常回复到敬请谅解！'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '高振', 'Sex': 1, 'Signature': '大家新年快乐，鸡年大吉！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '乐乐', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '洲际速递(澳洲)', 'Sex': 1, 'Signature': '人工客服上班时间为:周一至周六北京时间:09:30-17:30'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Kowloon City', 'RemarkName': '', 'NickName': '奔跑的蜗牛', 'Sex': 1, 'Signature': '给人生一个梦，圆梦一个人生'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'ash ériche', 'Sex': 1, 'Signature': '带图问价 没发的并不代表我没有'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Buenos Aires', 'RemarkName': '', 'NickName': '海带', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '\u202d', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Lucas Mayer', 'Sex': 1, 'Signature': 'Hi!'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Angel', 'Sex': 2, 'Signature': '<span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span><span class="emoji emoji1f497"></span>'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '夏薇', 'Sex': 2, 'Signature': '激情总在下半场'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '范超然 િ🌝ી', 'Sex': 1, 'Signature': '本屌是个边缘人'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Miss Panda', 'Sex': 0, 'Signature': '贱人就是矫情'}
# {'City': '', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '涛', 'Sex': 1, 'Signature': '十年纺识人，专注户外面料，特别推荐高耐气侯性色牢度户外面料'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '廖总', 'NickName': '阳光雨露leo', 'Sex': 1, 'Signature': '大半年的折腾最终划上句号！'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Corrientes', 'RemarkName': '', 'NickName': '徐弘 Mark', 'Sex': 1, 'Signature': '努力'}
# {'City': '泰安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '泰安 侯', 'Sex': 1, 'Signature': '不用了！！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': ' ', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Paris', 'RemarkName': '', 'NickName': '空白。', 'Sex': 2, 'Signature': '输了你。赢了世界又如何？'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '悉尼时光传媒', 'Sex': 1, 'Signature': '悉尼时光网互助平台'}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Michael Yan', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A.龙门客栈（截单）', 'Sex': 2, 'Signature': 'TEL:0406201818    网站: longmenkezhan.online'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '有病要读书', 'Sex': 0, 'Signature': '本号只用来公众号防失联，不闲聊，抱歉。'}
# {'City': '长沙', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '\uf3ce', 'Sex': 1, 'Signature': '此号已废'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '宇哥', 'Sex': 1, 'Signature': ''}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '张尧', 'Sex': 1, 'Signature': '加油吧'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'AAA🍲2011自助火锅酒楼KTV', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '清粉客服321', 'Sex': 2, 'Signature': ''}
# {'City': '鞍山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '鞍山海虹吊装', 'Sex': 1, 'Signature': '25-350吨吊车以及特种件，大件，小件运输18842086666'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '卡卡', 'Sex': 2, 'Signature': '无名指的爱'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '雷先生', 'NickName': '双车', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小湖南', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A小蜗牛租房平台_悉尼💕', 'Sex': 1, 'Signature': '需要发布房屋信息的同学，请把照片和描述发我。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Lucky_M💓', 'Sex': 2, 'Signature': '所有的遇见都是久别重逢'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Ivy', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Evelyn☀', 'Sex': 2, 'Signature': '不惮人言，不畏世俗，不弃自我，如此甚好。'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '梁国平', 'NickName': '进贤梁国平', 'Sex': 1, 'Signature': '做人要正、以诚相待！'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Marx', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Roy', 'Sex': 1, 'Signature': 'Valar morghulis. Valar dohaeris.'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'wenfei @ 贇', 'Sex': 1, 'Signature': 'Go'}
# {'City': 'Melbourne', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'A墨尔本互助社区', 'Sex': 2, 'Signature': '广告无处发？我来帮你免费推广'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'uber学校 0426917353', 'Sex': 2, 'Signature': '靠谱Uber新司机专业指导，时薪30-60刀。Code: d37ftuqbue'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'DaviDuan', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A.康康🇦🇺丶 ପଓ*ೃ࿐🚚', 'Sex': 2, 'Signature': '澳！洲！直！邮！'}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '孙悟饭 没及时回复加（Ljj5362）', 'Sex': 1, 'Signature': 'Alsis      主理人'}
# {'City': '青岛', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': 'dodo', 'Sex': 1, 'Signature': '一腔孤勇'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '望舒', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '中医推拿', 'Sex': 2, 'Signature': '帝王亨受每天不同的美女为你放松按摩推油踩背'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Cici（massage shop)', 'Sex': 2, 'Signature': '110A Victoria Road Drummoyne'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '澳中VINCENT牛肉', 'NickName': '澳中VINCENT', 'Sex': 1, 'Signature': 'Vincent（04169 19992）'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小妖 （换号了 加tuhaoxiaoniu）', 'Sex': 2, 'Signature': '换号了 tuhaoxiaoniu'}
# {'City': '大连', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': 'chen', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Alex', 'Sex': 1, 'Signature': "What doesn't kill you make you stronger"}
# {'City': '昆明', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': 'H', 'Sex': 1, 'Signature': '人生该走的弯路，其实一米也少不了！'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'hohoho', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '王可学姐', 'NickName': '王可', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'MMD Health客服', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '喵星人的烦恼', 'Sex': 2, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '淡定', 'Sex': 1, 'Signature': ''}
# {'City': '河北', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '葉森', 'Sex': 1, 'Signature': '善事善行'}
# {'City': '遵义', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '贵州', 'RemarkName': '', 'NickName': '酷乐', 'Sex': 1, 'Signature': ''}
# {'City': '台北市', 'ContactFlag': 8199, 'StarFriend': 0, 'Province': '台湾', 'RemarkName': '樊帆', 'NickName': '睡过头', 'Sex': 1, 'Signature': '昨天'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Viki奇', 'Sex': 2, 'Signature': '看得惯，走得出！ 看得惯他人的不是； 走得出自己的负能量！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Olbia-Tempio', 'RemarkName': '减50下次', 'NickName': '🔱俊哥哥 Ju', 'Sex': 1, 'Signature': '朋友圈一系列物品可验货， 接nike官网7折！'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '初', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'A02【开心】聊天专用', 'Sex': 2, 'Signature': '副微信长时间不回复请联系24小时服务热线：17701629061【开心】'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '杨安琪', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Michael Zou', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '薯条妹妹', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '-', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'X', 'Sex': 1, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '刘梅', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '任我行', 'Sex': 1, 'Signature': '欲穷千里目 更上一层楼'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '青年', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '87号', 'Sex': 1, 'Signature': 'easy'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Newstars移民顾问Jessie🎉', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'UGG630', 'Sex': 0, 'Signature': 'Shop 3   630 George st   Sydney 2000'}
# {'City': '金华', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '😈😈😈cyh', 'Sex': 1, 'Signature': '！'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '王芳', 'Sex': 2, 'Signature': '面朝大海，春暖花开'}
# {'City': '闸北', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Jamie', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '.', 'Sex': 1, 'Signature': '因为简单 所以自在'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '彼岸的星空', 'Sex': 1, 'Signature': '“那理想的彼岸也许不存在，我依然会走在那旅途上。”'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Summer', 'Sex': 1, 'Signature': '                   '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'St. Anthony', 'RemarkName': '订机票', 'NickName': '🌛lance', 'Sex': 2, 'Signature': '我有两小时的break'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': "' zZ", 'Sex': 1, 'Signature': '429918'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '我卖海参贼便宜', 'Sex': 1, 'Signature': '773'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'A-Jimmy', 'Sex': 1, 'Signature': '“人类的悲欢并不相通，我只觉得他们吵闹”'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': 'Feni', 'Sex': 1, 'Signature': ''}
# {'City': '南京', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '「Mr. Fu」', 'Sex': 1, 'Signature': ''}
# {'City': '海淀', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '粱荣', 'NickName': '梁荣', 'Sex': 1, 'Signature': '~'}
# {'City': '', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '暖阳(☆_☆)', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jeffrey', 'Sex': 1, 'Signature': ''}
# {'City': '扬州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'Tony', 'Sex': 1, 'Signature': '永远不要让看好你的人失望'}
# {'City': '池州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '高飞', 'Sex': 1, 'Signature': '厚德载物。一日真，二日忍'}
# {'City': '闵行', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'summer', 'Sex': 2, 'Signature': ''}
# {'City': '泰州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'John Zhang | 张俊松', 'Sex': 1, 'Signature': '高级地产置业投资顾问，真心待人，真诚做事！'}
# {'City': '深圳', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'MI', 'Sex': 1, 'Signature': ''}
# {'City': '惠州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Holly', 'Sex': 1, 'Signature': '只出正品鞋，需要什么鞋什么配色问我。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '畅灵 · 悉尼客服2号', 'Sex': 0, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'April.huang(^^)', 'Sex': 2, 'Signature': '祈祷全家都健康幸福！'}
# {'City': '合肥', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '张贺', 'Sex': 1, 'Signature': '我不入地狱 谁入地狱'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Tokyo', 'RemarkName': '', 'NickName': 'Ink私人顶级订制', 'Sex': 0, 'Signature': '主营chanel私人订制 一件起订 正品主号inkerzhang '}
# {'City': '海淀', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '启齐', 'Sex': 1, 'Signature': 'Actions speak louder than words'}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'Infinity傲娇班主任-Carina', 'Sex': 2, 'Signature': '做职业培训，我们是认真的！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '바보', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '唐🐝', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Alven', 'Sex': 1, 'Signature': '新年三大目标'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '大毛儿大毛儿大毛儿\U0001f988', 'Sex': 1, 'Signature': '想招大胸妹 想买大衣柜'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Lemon🍋', 'Sex': 2, 'Signature': '微信不要让我失望啊〜'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '夏天的雨熊玉林', 'Sex': 2, 'Signature': '人生最曼妙的风景，是内心的淡定与从容'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '多俪服装', 'Sex': 2, 'Signature': '欧美原单时装新款'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '时栗然', 'NickName': '西米', 'Sex': 2, 'Signature': '不要因为岁月静好而荒废了认知升级'}
# {'City': 'Toronto', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Ontario', 'RemarkName': '', 'NickName': 'Easyship-Chinese', 'Sex': 1, 'Signature': '专业中国转运全球'}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '李红新', 'Sex': 1, 'Signature': 'test'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '富富', 'Sex': 1, 'Signature': '生活就是问题叠着问题'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '卖货的冰冰', 'Sex': 0, 'Signature': '能力范围内鉴定 中意巴黎世家吧务组 春节期间正常发货'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '曾顺琪(雪狐)', 'Sex': 1, 'Signature': ''}
# {'City': '桂林', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广西', 'RemarkName': '', 'NickName': '听着肖邦吃泡面', 'Sex': 1, 'Signature': '眼底星空、'}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'moo', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '精时翻译Evan', 'Sex': 1, 'Signature': '一家专业靠谱的翻译公司'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '南派翻译', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A安康澳洲直邮批发代购 招代理！', 'Sex': 2, 'Signature': '专业澳洲直邮代购批发 欢迎咨询 招代理！ 奶粉保健品化妆品零食'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'VICKY🔆LEE', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '贷款 kevin', 'NickName': 'Keven', 'Sex': 1, 'Signature': '房贷，车贷，商业贷款，个人贷款'}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '東', 'Sex': 1, 'Signature': ''}
# {'City': '济宁', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '张志鸿', 'Sex': 1, 'Signature': 'sedimentation！'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '\u3000', 'Sex': 1, 'Signature': 'L’Aveugle par Amour♫'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '孔利明', 'NickName': 'klm', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '佟.', 'Sex': 1, 'Signature': ' '}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jingyi', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Frankfurt', 'RemarkName': '', 'NickName': '随缘自适', 'Sex': 1, 'Signature': '福往者福来 爱出者爱返'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '郭璇', 'Sex': 2, 'Signature': '愿你自己有充分的忍耐去担当， 有充分单纯的心去信仰。'}
# {'City': '和平', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '猪小仙', 'Sex': 2, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'YoYo', 'Sex': 2, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '杨波', 'Sex': 1, 'Signature': ''}
# {'City': '杭州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '何文清', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Matt张启凡', 'Sex': 1, 'Signature': 'Good things take time 🐌'}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '马珍平', 'NickName': '姆9s姥马', 'Sex': 2, 'Signature': ''}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'air up there', 'Sex': 1, 'Signature': '还我真实。'}
# {'City': '雅安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'will', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '九州搬运 and 东北情熏酱炒菜馆', 'Sex': 1, 'Signature': '打工--生意--事业  是人生的三个不同选择阶段。'}
# {'City': 'New York City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'jeremmy💭', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '媚姐', 'Sex': 0, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '街头杀猪的', 'Sex': 1, 'Signature': ''}
# {'City': '鸡西', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': '其实星空是为你点亮的', 'Sex': 1, 'Signature': '邂逅你，是生生世世的约定。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '收费咯', 'Sex': 1, 'Signature': '收费不点号'}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Dream.girls', 'Sex': 2, 'Signature': '尽善尽美<span class="emoji emoji2764"></span>️'}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '马志永13698003761', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 7, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '康芦钧', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': "'  Yw", 'Sex': 1, 'Signature': ' 一花一世界'}
# {'City': '佛山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '烽子', 'Sex': 1, 'Signature': '电信号码18128788880或联通号码18566030201'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '哭泣的卫生纸', 'Sex': 1, 'Signature': '只卖身，不卖艺〜'}
# {'City': '', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨姥姥', 'Sex': 0, 'Signature': ''}
# {'City': '大兴', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'A0任健,我善治腰，创旗，任医堂', 'Sex': 1, 'Signature': ''}
# {'City': '湘西', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Y', 'Sex': 1, 'Signature': '   只有拼'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '萌博士生活服务平台ʚ2ɞ', 'Sex': 1, 'Signature': '萌博士将随时解决你的需求'}
# {'City': '哈尔滨', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': 'Owen、🌟 张', 'Sex': 1, 'Signature': '<span class="emoji emoji1f3e0"></span>Noble Group| 诺达投资顾问|🏓️| 四月<span class="emoji emoji1f308"></span>'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '肉小美', 'Sex': 2, 'Signature': '我是肉肉哇~~我是菓菓妈'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '下雨天', 'Sex': 2, 'Signature': 'Be the best version of you'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '远山', 'Sex': 1, 'Signature': '没写完  等会'}
# {'City': '咸宁', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Bucky', 'Sex': 1, 'Signature': ''}
# {'City': '咸宁', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Wan', 'Sex': 1, 'Signature': 'kept hoping'}
# {'City': '湖州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '陳Tyang', 'Sex': 1, 'Signature': '佛系卖家看上问价'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Evan', 'Sex': 1, 'Signature': ''}
# {'City': '烟台', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '王伟好极了🐑🐏🐐', 'Sex': 1, 'Signature': '我就要naive'}
# {'City': '成都', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '李然至', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '晓', 'Sex': 2, 'Signature': '手机关机是因为没电啦！'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Verve', 'Sex': 1, 'Signature': 'Veni vidi vici '}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '毅🔝', 'Sex': 1, 'Signature': ''}
# {'City': '唐山', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '', 'NickName': 'linkin park ', 'Sex': 1, 'Signature': '_<span class="emoji emojiae"></span>_<span class="emoji emojiae"></span>'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Abu Dhabi', 'RemarkName': '', 'NickName': '.  love    MQ', 'Sex': 1, 'Signature': '本无意与众不同、<span class="emoji emoji1f6ac"></span>。怎耐何品味出众……'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨子秋', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Fanny Chen', 'Sex': 2, 'Signature': '有人先走有人留，没有人陪我到最后'}
# {'City': '杭州', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Leif.Yu', 'Sex': 1, 'Signature': ''}
# {'City': '沈阳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': 'Beyond', 'Sex': 1, 'Signature': '人在江湖，身不由己。'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'London', 'RemarkName': '新裤子XL', 'NickName': '小琦™', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Jasons Pharmacy Supplies', 'Sex': 1, 'Signature': ''}
# {'City': '广州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Alfonso', 'Sex': 1, 'Signature': ''}
# {'City': '哈尔滨', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '黑龙江', 'RemarkName': '', 'NickName': '😄 傲然', 'Sex': 1, 'Signature': '面对未知的世界，你需要的只是好奇心'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'D', 'Sex': 1, 'Signature': 'why so serious？'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '王王山而', 'Sex': 1, 'Signature': '不过是花瓣 微不足道'}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'L', 'Sex': 1, 'Signature': ' '}
# {'City': '河西', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '赵舒豪', 'Sex': 1, 'Signature': 'Vita Dolce. '}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '我想我是海', 'Sex': 1, 'Signature': '天若有情天亦老'}
# {'City': '虹口', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '我全要', 'Sex': 1, 'Signature': '我全要'}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '风风火火', 'Sex': 2, 'Signature': '亲们，请保存我最新手机号18109293228...原号码即将停用。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '王佐', 'NickName': 'W', 'Sex': 1, 'Signature': 'models &amp; bottles'}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Superlit', 'Sex': 1, 'Signature': ''}
# {'City': '福州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '海天一', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': '🐻 哦哦哦', 'Sex': 1, 'Signature': '可能还会再遇见一个你'}
# {'City': '成都', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Tough girl 娟 🐯', 'Sex': 2, 'Signature': '做人，简单就好。生活，宁静就好。'}
# {'City': '岳阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': '张凯西', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '向日葵', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杨帆', 'Sex': 1, 'Signature': ''}
# {'City': '南京', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '玲玲', 'Sex': 2, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Albus🔮', 'Sex': 1, 'Signature': '为曾经的梦想也努力一回。'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '不可一世k', 'Sex': 1, 'Signature': '换汇找我'}
# {'City': '合肥', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '🍁', 'Sex': 1, 'Signature': '哩哩哩哩哩哩哩哩哩lll'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Amber澳洲代购', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Tina Wu', 'Sex': 2, 'Signature': 'Looking for like-minded friends '}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'BingBing🎶👣', 'Sex': 2, 'Signature': '一生再也不敢那么勇敢，为你！'}
# {'City': '绍兴', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'adǎ', 'Sex': 1, 'Signature': ''}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '辉', 'Sex': 1, 'Signature': '尚和合，求大同，一切行止由心。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Fukuoka', 'RemarkName': '', 'NickName': 'kin', 'Sex': 1, 'Signature': "We're the nobodies. Wanna be somebodies "}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Yue', 'Sex': 2, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '尚贤', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '张梦婷', 'NickName': '7-11💓', 'Sex': 2, 'Signature': '包子脸，豆腐心！'}
# {'City': '文山', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': 'Leon Zhu', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Studyz', 'Sex': 1, 'Signature': 'Videomaker'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '宋卫', 'Sex': 1, 'Signature': '真情是一生永远不变的主题!爱是我们永恒不变的神话！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '一一一一一一一一', 'Sex': 1, 'Signature': '          祈禱未來！'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '努力奋斗', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '嘿～请叫我余先生＂', 'Sex': 1, 'Signature': '躲得过对酒当歌的夜，躲不过四下无人的街……'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '大头爸爸爸爸爸爸爸爸爸爸', 'Sex': 1, 'Signature': '                                                     CMS<span class="emoji emoji2764"></span>️'}
# {'City': '苏州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'leoking', 'Sex': 1, 'Signature': 'Forza Milan！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'juice', 'Sex': 1, 'Signature': '怒马鲜衣。'}
# {'City': '广州', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'PK', 'Sex': 1, 'Signature': '你那么尊贵，怎么不要个王位'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Hamburg', 'RemarkName': '', 'NickName': '😊🇩🇪珊珊王', 'Sex': 2, 'Signature': '不忘初心。'}
# {'City': 'New York City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'UNIELITE 直发需求至签名电邮', 'Sex': 1, 'Signature': '如不在 请直发需求至 unieliteworks@hotmail.com'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Merrick', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'MATTHEW', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '蓉', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Daric', 'Sex': 1, 'Signature': ' '}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '董某', 'Sex': 1, 'Signature': ''}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': '阿汪', 'Sex': 1, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '毛线！', 'Sex': 1, 'Signature': '感谢相遇'}
# {'City': '徐汇', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '不愿透露姓名的赵伟先生', 'Sex': 1, 'Signature': '准会想起父亲带他去参观冰块的那个遥远的下午。'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Au. 夏因🏅Dian鋪 ®', 'Sex': 1, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '👑 谢婷🌛 🎵', 'Sex': 2, 'Signature': 'To fast to live To young to die'}
# {'City': '渝北', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '重庆', 'RemarkName': '', 'NickName': '（kol）', 'Sex': 1, 'Signature': ''}
# {'City': '廊坊', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '', 'NickName': 'Sunny Bernabeu', 'Sex': 1, 'Signature': 'Mont-Joie！Charge！Ура！'}
# {'City': '朝阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '东东', 'Sex': 1, 'Signature': '出发，向着远方'}
# {'City': '西安', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': 'Ding', 'Sex': 1, 'Signature': ''}
# {'City': '黄浦', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'Clark', 'Sex': 1, 'Signature': ''}
# {'City': '海淀', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '晓晓', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '丁小雪', 'Sex': 2, 'Signature': '生命不息，折腾不止~ <span class="emoji emoji1f4aa"></span>'}
# {'City': '深圳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Wang', 'Sex': 1, 'Signature': ''}
# {'City': 'Portland City', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Oregon', 'RemarkName': '', 'NickName': 'The lamb of GOD$', 'Sex': 1, 'Signature': 'Fate for what？'}
# {'City': 'Melbourne', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': '🙈🙉🙊', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '杰瑞', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Auckland', 'RemarkName': '', 'NickName': '蔡懿', 'Sex': 1, 'Signature': '《Catch Me If You Can》I Am The Second Mouse ！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'EGO', 'Sex': 0, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Victoria', 'RemarkName': '', 'NickName': 'Jake Hu', 'Sex': 1, 'Signature': 'conservatory，aurora，swanston central指定出租管理中介'}
# {'City': '淄博', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': '阿威', 'Sex': 1, 'Signature': '。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': 'IGA 奶粉', 'NickName': '萬劫', 'Sex': 1, 'Signature': '佛说：十方世界，众生平等，我说：八荒六合，唯我独尊。'}
# {'City': '厦门', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '🔱VIP专属服务™Vivian', 'Sex': 2, 'Signature': '<span class="emoji emoji1f493"></span><span class="emoji emoji1f493"></span>微信没回，直接谈语音'}
# {'City': '湖州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '老徐👣', 'NickName': '唐唐', 'Sex': 2, 'Signature': '享受人生'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '广告号两只考拉🐨 澳品直邮', 'Sex': 0, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'A🍉🍓嘎嘎', 'Sex': 2, 'Signature': '晚上11点半后自助下单哦~'}
# {'City': '泉州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': 'peng  😂 Te【国潮代发】', 'Sex': 1, 'Signature': '老牌微商，国潮、美潮、奢潮，支持代发'}
# {'City': 'Sydney', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Eric', 'Sex': 1, 'Signature': ''}
# {'City': '苏州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '葛桂月', 'Sex': 2, 'Signature': '有时无牵无挂不是挺好？'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '山西', 'RemarkName': '', 'NickName': '橘子', 'Sex': 2, 'Signature': '岂能尽如人意'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '三商', 'Sex': 1, 'Signature': '三商客服在线时间:  周一至周五 悉尼时间 11am - 5pm'}
# {'City': '宁波', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '杨哥  (', 'Sex': 1, 'Signature': '全网爆款 实力供货'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Laffa Girl悉尼', 'Sex': 2, 'Signature': '<span class="emoji emoji1f4de"></span> ：+61452139950  网站：www.laffagirl.live'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '优品-营销号（广告号）', 'Sex': 0, 'Signature': '广告号-不回答问题与接单<span class="emoji emoji1f64f"></span>'}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '小把戏', 'Sex': 1, 'Signature': '平平安安就好'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Struggle', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'BASEBONE', 'Sex': 2, 'Signature': '□'}
# {'City': '温州', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '阿芳（创新吸塑包装）', 'Sex': 1, 'Signature': '有目标人生才有意义！吸塑包装有需要的找我！'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '皇冠店搜aramer加新号ARAMER7', 'Sex': 0, 'Signature': 'tb搜店铺：aramer'}
# {'City': '青岛', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '山东', 'RemarkName': '', 'NickName': 'ADIDAS NIKE批发一件代发招代理', 'Sex': 1, 'Signature': '专注原单，专注高品质'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Alstonzzzzzzzzz', 'Sex': 0, 'Signature': '鞋子aj yeezy 喷泡 等 衣服 sup palace 等，接nike官网7.5折代购'}
# {'City': '张家界', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Eat—Yourself  ', 'Sex': 1, 'Signature': '-没有退路的灵魂才会呐喊出声'}
# {'City': 'Sydney', 'ContactFlag': 73729, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '谢小妞狠纠结澳洲代购', 'Sex': 2, 'Signature': '设计师品牌集合平台 顺丰到付'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Kai澳洲代购', 'Sex': 1, 'Signature': ''}
# {'City': '厦门', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '悟小空', 'Sex': 2, 'Signature': ''}
# {'City': '徐汇', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '上海（双喜）全国接单号', 'Sex': 1, 'Signature': '进门报双喜^，预约电话:18321668078'}
# {'City': '南开', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '', 'NickName': '烙✿印', 'Sex': 1, 'Signature': '毫不犹豫，绝不退缩。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '对的啊', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Dubayy', 'RemarkName': '', 'NickName': '陈振宇', 'Sex': 1, 'Signature': ''}
# {'City': '南充', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '噘噘嘴（无扰清粉）', 'Sex': 2, 'Signature': '如果这个号无人回复，请加 juejuezui666'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '鞋世界', 'Sex': 2, 'Signature': '宠爱天使奢侈品'}
# {'City': '温州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '李晔', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'MD Ranking面岛爱购', 'Sex': 0, 'Signature': '澳洲最全最划算的日韩美妆店<span class="emoji emoji2764"></span>️周1-7营业时间11am-10pm'}
# {'City': 'Toronto', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'Ontario', 'RemarkName': '', 'NickName': '顾大师下单号', 'Sex': 1, 'Signature': '只做好货 屏蔽不加 默认顺丰到付 '}
# {'City': '郑州', 'ContactFlag': 8193, 'StarFriend': 0, 'Province': '河南', 'RemarkName': '', 'NickName': 'ivy', 'Sex': 2, 'Signature': ''}
# {'City': '惠州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '坚坚', 'Sex': 1, 'Signature': '心有所戒，心有所仰，心有所获！'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '甜★甜♂', 'Sex': 2, 'Signature': '没有公主的命，但有一颗女王的心！'}
# {'City': '湾仔区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '香港', 'RemarkName': '', 'NickName': '段小旺', 'Sex': 1, 'Signature': '弓长双木'}
# {'City': '阜新', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '叶堃.', 'Sex': 1, 'Signature': ''}
# {'City': '宝山', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'SkyHoke', 'Sex': 1, 'Signature': ''}
# {'City': '闵行', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '大寒', 'Sex': 1, 'Signature': ''}
# {'City': '海口', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '海南', 'RemarkName': '鼻炎小犀牛', 'NickName': 'Devil', 'Sex': 1, 'Signature': 'Baby you light up my world like nobody else'}
# {'City': '成都', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '困兽之斗', 'Sex': 1, 'Signature': '有朝一日龙得水，我让长江水倒流'}
# {'City': '深圳', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '群', 'NickName': '珷玞', 'Sex': 1, 'Signature': '故事从何说起'}
# {'City': '常州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '陈禹啸', 'Sex': 1, 'Signature': ''}
# {'City': '琼海', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '海南', 'RemarkName': '', 'NickName': '咦', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Edgar', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '大熊', 'NickName': '熊俊', 'Sex': 1, 'Signature': 'unɾ ɓuoıx'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '梦云', 'Sex': 2, 'Signature': ''}
# {'City': '成都', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': 'Simon', 'Sex': 1, 'Signature': '许你十里桃花任你大浪狂沙'}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '路洁', 'Sex': 2, 'Signature': '该吃吃该喝喝，该玩玩该乐乐，破事别往心里搁'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '发型师', 'NickName': '蓝调@Eric', 'Sex': 1, 'Signature': '心灵的沉淀需要真实的经历去完成，继续走继续失去'}
# {'City': '常州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'Treasure❇', 'Sex': 1, 'Signature': '找乐趣'}
# {'City': 'Vancouver', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'British Columbia', 'RemarkName': '', 'NickName': '小熊猫🐼', 'Sex': 2, 'Signature': '只做最好的卖家！品质保证！招代理 一件代发！'}
# {'City': '深圳', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '韩昊育😳', 'Sex': 1, 'Signature': '我没有任何其他微信号，谨防假冒'}
# {'City': '长沙', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '湖南', 'RemarkName': '', 'NickName': 'Joe-Jo', 'Sex': 1, 'Signature': 'I’m afraid I haven’t been alive enough. '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '陶然亭人', 'Sex': 1, 'Signature': 'climber'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '亨利', 'NickName': '专修宝马奔驰亨利', 'Sex': 1, 'Signature': '诚信用心做车710 Pennant hills road carlingford'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '陶陶', 'Sex': 1, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '小白兔。', 'Sex': 2, 'Signature': '                哦'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'M', 'Sex': 1, 'Signature': 'Phil-'}
# ...
# {'City': 'Edinburgh', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Scotland', 'RemarkName': '', 'NickName': '廖宝宝', 'Sex': 2, 'Signature': '物极必反'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'Assen', 'RemarkName': '', 'NickName': '-', 'Sex': 2, 'Signature': '不可口'}
# {'City': '绍兴', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Neo', 'Sex': 1, 'Signature': '<span class="emoji emoji1f197"></span>'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '@', 'Sex': 1, 'Signature': '\U0001f940chilling'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '【Anti】Savitar 在线', 'Sex': 1, 'Signature': 'Anti主理人 和homie同富有 没找到的拿图来 <span class="emoji emoji1f43e"></span>'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Paris', 'RemarkName': '', 'NickName': '.', 'Sex': 1, 'Signature': 'ㅡ'}
# {'City': '漳州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '福建', 'RemarkName': 'UK8', 'NickName': 'lchild', 'Sex': 1, 'Signature': '熬过去就好了'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Mr.7vtty.L¡η', 'Sex': 1, 'Signature': ''}
# {'City': '宁波', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '柒爷🐙MuffinMan🐸🐢', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Andy摄影师', 'Sex': 1, 'Signature': '余生不是你。人丑事多家里穷，没车没房没存款'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Kazan', 'RemarkName': '', 'NickName': '好名字可以让你的朋友更难记住你。', 'Sex': 1, 'Signature': '靠自己然后一步一步。'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '惹人生气小能手', 'Sex': 2, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '茤茤MaMa', 'Sex': 2, 'Signature': ''}
# {'City': '浦东新区', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': 'B__Y__N__M__R', 'Sex': 1, 'Signature': '2019年更加努力........'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Dubayy', 'RemarkName': '', 'NickName': '老K', 'Sex': 1, 'Signature': '沧海桑田，白云苍狗'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '一件代发', 'RemarkName': '', 'NickName': '潮流作曲家', 'Sex': 1, 'Signature': '入圈四年|爆款供货|圈内信誉自查|只收私代1888|顾客自觉加价20'}
# {'City': '昆明', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': 'awakening.', 'Sex': 2, 'Signature': '為你鍾情 傾我至誠、'}
# {'City': '河东', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '天津', 'RemarkName': '哈哈4', 'NickName': 'GIorgio', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'J.$low', 'Sex': 1, 'Signature': ''}
# {'City': '湾仔区', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '香港', 'RemarkName': '', 'NickName': 'kaiko鋳', 'Sex': 1, 'Signature': '心怀希望，就永远有希望。'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Nancy 袁籣（澳洲手机）', 'Sex': 0, 'Signature': '完美人生'}
# {'City': '西安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': 'jason', 'NickName': 'Jas', 'Sex': 1, 'Signature': 'the math romantic'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': 'Firenze', 'RemarkName': '', 'NickName': 'ΟЦТSTΛИDIИG', 'Sex': 1, 'Signature': '重新做人'}
# {'City': '宜宾', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '四川', 'RemarkName': '', 'NickName': '分割世界的桥', 'Sex': 1, 'Signature': '李问死了 所以李问永远是李问'}
# {'City': '黄浦', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '。。。', 'Sex': 1, 'Signature': '不熬夜'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Lower Austria', 'RemarkName': '', 'NickName': '.........', 'Sex': 1, 'Signature': '........'}
# {'City': 'Sydney', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '😍JessicaYu😍', 'Sex': 2, 'Signature': '销售，绝不是降低身份去取悦客户，而是像朋友一样给予合理的建议'}
# {'City': '', 'ContactFlag': 73731, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '🐋', 'Sex': 2, 'Signature': '生人勿近               .'}
# {'City': '昆明', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '云南', 'RemarkName': '', 'NickName': '咸鱼', 'Sex': 1, 'Signature': ''}
# {'City': '武汉', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '湖北', 'RemarkName': '', 'NickName': 'Benevolence.', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '.cccb.', 'Sex': 1, 'Signature': ' 做个好人。'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '没没没道理', 'Sex': 1, 'Signature': '最初的梦 谁都想笑着做完'}
# {'City': '广州', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '我走路带风', 'Sex': 1, 'Signature': '#                       你相信来日方长吗?                  '}
# {'City': '南京', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': '西瓜皮太郎', 'Sex': 1, 'Signature': ''}
# {'City': '静安', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '劉', 'Sex': 2, 'Signature': '你若爱，生活哪里都可爱'}
# {'City': '宝山', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '上海', 'RemarkName': '', 'NickName': '丰丰.', 'Sex': 1, 'Signature': ''}
# {'City': '绍兴', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'Pan。W✨', 'Sex': 1, 'Signature': '万年太久，只争朝夕'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Danny', 'Sex': 1, 'Signature': '不知疲倦'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Anti', 'Sex': 1, 'Signature': ''}
# {'City': '南昌', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '贰0壹久', 'Sex': 2, 'Signature': '平安喜乐'}
# {'City': '石家庄', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '河北', 'RemarkName': '衣服T', 'NickName': 'yahooooo', 'Sex': 1, 'Signature': '                                  年轻的心 热泪盈眶'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Steven:)', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Sherly GBI联合创始人&amp; R+F', 'Sex': 2, 'Signature': '微信太久没回请打电话!'}
# {'City': '朝阳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'Lucifer.柴', 'Sex': 1, 'Signature': '无心'}
# {'City': 'Miyazaki-shi', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'Miyazaki-ken', 'RemarkName': '', 'NickName': '-平凡', 'Sex': 1, 'Signature': '学会把“自己”藏起来'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '哈嘿', 'NickName': '🌤', 'Sex': 1, 'Signature': ''}
# {'City': '南通', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '江苏', 'RemarkName': '', 'NickName': 'lo2', 'Sex': 1, 'Signature': 'hugerab@qq.com'}
# {'City': '深圳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'ZHENGX', 'Sex': 1, 'Signature': '╳Too Much Sauce╳'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '宁婷', 'Sex': 2, 'Signature': ''}
# {'City': '深圳', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'Dciken', 'Sex': 1, 'Signature': 'Your emptiness and your sickening soul'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'ubee', 'Sex': 1, 'Signature': '独立自由与人为善'}
# {'City': '台州', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': 'francis zfb扫码', 'Sex': 1, 'Signature': '人一直在 有事私聊'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Dublin', 'RemarkName': '', 'NickName': 'Hepburn', 'Sex': 1, 'Signature': '＂这个季节很干净＂'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '雷克雅未克儿', 'Sex': 1, 'Signature': '已事过境迁'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Jūne', 'Sex': 1, 'Signature': '     游龙当归海'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '萌', 'Sex': 2, 'Signature': '甜甜圈🍩'}
# {'City': '深圳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '白白白', 'Sex': 1, 'Signature': '随遇而安'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '十二', 'Sex': 1, 'Signature': '很忙 别烦'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '💜', 'RemarkName': '', 'NickName': 'ᴘᴇᴀᴄʜ ᴊᴀᴍ', 'Sex': 2, 'Signature': ' ☃︎'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Deom 1', 'Sex': 1, 'Signature': 'Following \\ 2020'}
# {'City': '韶关', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '卖家', 'NickName': 'Alexxx_x', 'Sex': 1, 'Signature': '學會在冷靜中瘋狂提速  \\  『 ᴄɴʀɪsᴇ. 」 '}
# {'City': '沈阳', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '长大', 'Sex': 2, 'Signature': ''}
# {'City': 'Port Augusta', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'South Australia', 'RemarkName': '', 'NickName': '不易', 'Sex': 1, 'Signature': '3915.8'}
# {'City': 'Sydney', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '糖小糖', 'Sex': 2, 'Signature': '願妳熬得過深夜痛哭 天亮依然鏗鏘如故'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Siwei | 思危 🔰', 'Sex': 1, 'Signature': '不积跬步，无以至千里'}
# {'City': '杭州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '别样de', 'Sex': 1, 'Signature': ''}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'ASH1a.Ashfield.凤雅堂', 'Sex': 2, 'Signature': '澳洲厂家品牌代理商，专业美妆顾问，一件无痕代发，可支付宝微信'}
# {'City': 'New York', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'New York', 'RemarkName': '', 'NickName': 'ㅤ', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '亻', 'Sex': 2, 'Signature': '孤岛'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'AuchoiceWL😊（Healthyline接单', 'Sex': 1, 'Signature': 'waterlooHealthyLine直邮中国 营业时间（国内08:00-17:00）'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '曹丽', 'Sex': 2, 'Signature': '美梦成真'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A🏊游泳健身-阿磊🍭', 'Sex': 1, 'Signature': '  R  1   3   5  ┗╋╋┫   2  4  6'}
# {'City': '海淀', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': '邓kai', 'Sex': 1, 'Signature': '不诚信不加、爱装B不加、无意图不加、不爱数据不加'}
# {'City': '广州', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': '叶子', 'Sex': 1, 'Signature': '用仅有的青春赌明天'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '黄神仙', 'Sex': 1, 'Signature': 'hwjyz000602'}
# {'City': '', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'San', 'Sex': 1, 'Signature': '3301'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'A💓sun', 'Sex': 2, 'Signature': '憋疯啦！！！'}
# {'City': 'Sydney', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': '澳有鞋子总客服', 'Sex': 2, 'Signature': '在线时间 8:00-11:30  12:30-5:00'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'Seoul', 'RemarkName': '', 'NickName': 'Taeko-🌗', 'Sex': 1, 'Signature': '学到的要教人 赚到的要给人'}
# {'City': '九龙城区', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '香港', 'RemarkName': '', 'NickName': 'Auzggg', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小方', 'Sex': 1, 'Signature': 'To be a batter man'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '', 'NickName': 'z', 'Sex': 1, 'Signature': ''}
# {'City': '沈阳', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '辽宁', 'RemarkName': '', 'NickName': '肉肉', 'Sex': 1, 'Signature': ''}
# {'City': '湖州', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': 'Kaiwa UK9', 'NickName': '我最爱的男人', 'Sex': 1, 'Signature': '     '}
# {'City': 'Wilmington City', 'ContactFlag': 1, 'StarFriend': 0, 'Province': 'North Carolina', 'RemarkName': '', 'NickName': 'Jeremy Li', 'Sex': 1, 'Signature': '克己 慎独'}
# {'City': '合肥', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': 'Polaris', 'Sex': 2, 'Signature': '做一个情绪稳定的成年人'}
# {'City': '', 'ContactFlag': 8195, 'StarFriend': 0, 'Province': 'Kyoto', 'RemarkName': '', 'NickName': '🌈Levi Tan', 'Sex': 1, 'Signature': 'Universe '}
# {'City': '合肥', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '安徽', 'RemarkName': '', 'NickName': '赵豪', 'Sex': 1, 'Signature': 'NOMAD '}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小虎鯨胡八一 ฅ*ↀωↀ*ฅ', 'Sex': 2, 'Signature': '『請伱收起一切相信這晚只是一場遊戲一場夢。』'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'DankeYjm', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'Vienna', 'RemarkName': '', 'NickName': '小陈', 'Sex': 2, 'Signature': '结婚不等于幸福，单身也不意味着不幸！因为我们出生就一个人！'}
# {'City': '海淀', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '北京', 'RemarkName': '操', 'NickName': '鲁 大 少', 'Sex': 1, 'Signature': 'Heartless.'}
# {'City': '厦门', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '福建', 'RemarkName': '', 'NickName': '猪小悦', 'Sex': 2, 'Signature': '人生在世  及时行乐tough times do not last tough people do'}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'Zero -Two', 'Sex': 1, 'Signature': '只要最后是你，就好。'}
# {'City': '南昌', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': '杨廷弼（不公子）', 'Sex': 1, 'Signature': 'u are my sunshine'}
# {'City': '西安', 'ContactFlag': 65539, 'StarFriend': 0, 'Province': '陕西', 'RemarkName': '', 'NickName': '张小宝', 'Sex': 2, 'Signature': ''}
# {'City': '潮州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '广东', 'RemarkName': '', 'NickName': 'JJ', 'Sex': 1, 'Signature': 'sj'}
# {'City': 'Sydney', 'ContactFlag': 32771, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Whitney-銀行房貸經理℡', 'Sex': 2, 'Signature': 'nab Home Lending Manager国民銀行貸款經理0405626881'}
# {'City': '杭州', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '浙江', 'RemarkName': '', 'NickName': '隺鸟隺鸟子', 'Sex': 2, 'Signature': ''}
# {'City': '', 'ContactFlag': 65537, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '🌟Gensin（支持花呗）', 'Sex': 1, 'Signature': ''}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': '小智荣', 'Sex': 1, 'Signature': '爱腻嘉真是太好了'}
# {'City': 'Sydney', 'ContactFlag': 3, 'StarFriend': 0, 'Province': 'New South Wales', 'RemarkName': '', 'NickName': 'Sun jack (Snap Fitness trainer )', 'Sex': 1, 'Signature': 'Nothing can pull me back'}
# {'City': '', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '上海', 'RemarkName': 'UK10 L M', 'NickName': 'William', 'Sex': 1, 'Signature': 'I will be nicer if you be smarter.'}
# {'City': '', 'ContactFlag': 1, 'StarFriend': 0, 'Province': '', 'RemarkName': '', 'NickName': 'vv', 'Sex': 1, 'Signature': '把兴趣上升到态度'}
# {'City': '九江', 'ContactFlag': 3, 'StarFriend': 0, 'Province': '江西', 'RemarkName': '', 'NickName': "C'est la vie", 'Sex': 2, 'Signature': '坚持努力，该来的都在路上。'}

# %%
# 导入Pie组件，用于生成饼图
from pyecharts import Pie

# 获取所有性别
sex = []
with open('friends.txt', mode='r', encoding='utf-8') as f:
    rows = f.readlines()
    for row in rows:
        sex.append(row.split(',')[2])
# print(sex)

# 统计每个性别的数量
attr = ['Boys', 'Girls', 'Non']
value = [sex.count('1'), sex.count('2'), sex.count('0')]

pie = Pie('Friends Gender', 'Total Number of Friends：%d' % len(sex), title_pos='center')
pie.add('', attr, value, radius=[30, 75], rosetype='area', is_label_show=True,
        is_legend_show=True, legend_top='bottom')
#pie.show_config()
pie.render('Friends Gender.html')

# %%
# 处理地名数据，解决坐标文件中找不到地名的问题
def handle(cities):
    # print(len(cities), len(set(cities)))

    # 获取坐标文件中所有地名
    data = None
    with open(
            '/anaconda3/lib/python3.5/site-packages/pyecharts/datasets/city_coordinates.json',
            mode='r', encoding='utf-8') as f:
        data = json.loads(f.read())  # 将str转换为json

    # 循环判断处理
    data_new = data.copy()  # 拷贝所有地名数据
    for city in set(cities):  # 使用set去重
        # 处理地名为空的数据
        if city == '':
            while city in cities:
                cities.remove(city)
        count = 0
        for k in data.keys():
            count += 1
            if k == city:
                break
            if k.startswith(city):  # 处理简写的地名，如 达州市 简写为 达州
                # print(k, city)
                data_new[city] = data[k]
                break
            if k.startswith(city[0:-1]) and len(city) >= 3:  # 处理行政变更的地名，如县改区 或 县改市等
                data_new[city] = data[k]
                break
        # 处理不存在的地名
        if count == len(data):
            while city in cities:
                cities.remove(city)

    # print(len(data), len(data_new))

    # 写入覆盖坐标文件
    with open(
            '/anaconda3/lib/python3.5/site-packages/pyecharts/datasets/city_coordinates.json',
            mode='w', encoding='utf-8') as f:
        f.write(json.dumps(data_new, ensure_ascii=False))  # 将json转换为str

# %%
# 导入Counter类，用于统计值出现的次数
from collections import Counter
# 导入Geo组件，用于生成地理坐标类图
from pyecharts import Geo
import json
# 导入Bar组件，用于生成柱状图
from pyecharts import Bar

# 数据可视化
def render():
    # 获取所有城市
    cities = []
    with open('friends.txt', mode='r', encoding='utf-8') as f:
        rows = f.readlines()
        for row in rows:
            city = row.split(',')[4]
            if city != '':  # 去掉城市名为空的值
                cities.append(city)

    # 对城市数据和坐标文件中的地名进行处理
    handle(cities)

    # 统计每个城市出现的次数
    data = Counter(cities).most_common()  # 使用Counter类统计出现的次数，并转换为元组列表
    #print(data)
    #data_china = data[1:]

    # 根据城市数据生成地理坐标图
    #geo = Geo('好友位置分布', '', title_color='#fff', title_pos='center', width=1200, height=600,
    #          background_color='#404a59')
    #attr, value = geo.cast(data_china)
    #geo.add('', attr, value, visual_range=[0, 500],
    #        visual_text_color='#fff', symbol_size=15,
    #        is_visualmap=True, is_piecewise=True)
    #geo.render('好友位置分布.html')

    # 根据城市数据生成柱状图
    data_top10 = Counter(cities).most_common(10)  # 返回出现次数最多的20条
    bar = Bar('Friends City TOP10', '', title_pos='center', width=1200, height=600)
    attr, value = bar.cast(data_top10)
    #print(attr)
    #print(value)
    bar.add('',attr, value, is_visualmap=True, visual_text_color='#fff', is_more_utils=True,
            is_label_show=True)
    bar.render('Friends City TOP10.html')
if __name__ == '__main__':
    render()

# %%
# 导入Counter类，用于统计值出现的次数
from collections import Counter
# 导入Geo组件，用于生成地理坐标类图
from pyecharts import Geo
import json
# 导入Bar组件，用于生成柱状图
from pyecharts import Bar

cities = []
with open('friends.txt', mode='r', encoding='utf-8') as f:
    rows = f.readlines()
    for row in rows:
        city = row.split(',')[4]
        if city != '':  # 去掉城市名为空的值
            cities.append(city)

# 对城市数据和坐标文件中的地名进行处理
handle(cities)

# 统计每个城市出现的次数
data = Counter(cities).most_common()  # 使用Counter类统计出现的次数，并转换为元组列表
#print(data)
#data_china = data[1:]

# 根据城市数据生成地理坐标图
#geo = Geo('好友位置分布', '', title_color='#fff', title_pos='center', width=1200, height=600,
#          background_color='#404a59')
#attr, value = geo.cast(data_china)
#geo.add('', attr, value, visual_range=[0, 500],
#        visual_text_color='#fff', symbol_size=15,
#        is_visualmap=True, is_piecewise=True)
#geo.render('好友位置分布.html')

# 根据城市数据生成柱状图
data_top10 = Counter(cities).most_common(10)  # 返回出现次数最多的20条
bar = Bar('Friends City TOP10', '', title_pos='center', width=1200, height=600)
attr, value = bar.cast(data_top10)
#print(attr)
#print(value)
bar.add('',attr, value, is_visualmap=True, visual_text_color='#fff', is_more_utils=True,
        is_label_show=True)
#bar.render('Friends City TOP20.html')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e5d021b23b2c47e0be0028e87160eef8" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e5d021b23b2c47e0be0028e87160eef8 = echarts.init(document.getElementById('e5d021b23b2c47e0be0028e87160eef8'), 'light', {renderer: 'canvas'});
#
# var option_e5d021b23b2c47e0be0028e87160eef8 = {
#     "legend": [
#         {
#             "orient": "horizontal",
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "splitLine": {
#                 "show": true
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "show": true,
#             "inverse": false,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8
#             }
#         }
#     ],
#     "series_id": 8868891,
#     "series": [
#         {
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": true
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "seriesId": 8868891,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "data": [
#                 122,
#                 73,
#                 61,
#                 61,
#                 55,
#                 32,
#                 29,
#                 28,
#                 28,
#                 27
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             },
#             "dataZoom": {
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "show": true
#             },
#             "magicType": {
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "tiled": "\u5e73\u94fa",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0"
#                 },
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "center",
#             "text": "Friends City TOP10",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "category",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u5357\u660c",
#                 "\u6df1\u5733",
#                 "\u676d\u5dde",
#                 "\u5e7f\u5dde",
#                 "\u6210\u90fd",
#                 "\u5357\u4eac",
#                 "\u82cf\u5dde",
#                 "\u5b81\u6ce2",
#                 "\u671d\u9633",
#                 "\u6b66\u6c49"
#             ],
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "inverse": false,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "visualMap": {
#         "calculable": true,
#         "type": "continuous",
#         "text": [
#             "high",
#             "low"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "max": 100,
#         "textStyle": {
#             "color": "#fff"
#         },
#         "splitNumber": 5,
#         "left": "left",
#         "showLabel": true,
#         "min": 0,
#         "top": "bottom"
#     }
# };
# myChart_e5d021b23b2c47e0be0028e87160eef8.setOption(option_e5d021b23b2c47e0be0028e87160eef8);
#
#     });
# </script>

# %%
# 导入Counter类，用于统计值出现的次数
from collections import Counter
# 导入Geo组件，用于生成地理坐标类图
from pyecharts import Geo
import json
# 导入Bar组件，用于生成柱状图
from pyecharts import Bar
import re

def render():
    # 获取所有城市
    r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
    cities = []
    with open('friends.txt', mode='r', encoding='utf-8') as f:
        rows = f.readlines()
        for row in rows:
            city = row.split(',')[4]
            city = re.sub(r1, '', city)
            if city != '':  # 去掉城市名为空的值
                cities.append(city)
    # 对城市数据和坐标文件中的地名进行处理
    handle(cities)
    data = Counter(cities).most_common()  # 使用Counter类统计出现的次数，并转换为元组列表
    data_china = data
    data_china.pop(14)
    #data_china.pop(26)
    #data_china.pop(93)
    #data_china.pop(132)
    #data_china.pop(141)
    #data_china.pop(151)
    #data_china.pop(160)
    #data_china.pop(163)
    #data_china.pop(169)
    #data_china.pop(200)
    #data_china.pop(208)
    #data_china.pop(221)
    for i in range(len(data_china)):
        print(i)
        print(data_china[i])
    # 根据城市数据生成地理坐标图
    geo = Geo('好友位置分布', '', title_color='#fff', title_pos='center', width=1200, height=600,
              background_color='#404a59')
    attr, value = geo.cast(data)
    geo.add('', attr, value, visual_range=[0, 500],
            visual_text_color='#fff', symbol_size=15,
            is_visualmap=True, is_piecewise=True)
    geo.render('好友位置分布.html')
    
if __name__ == '__main__':
    print(render())
# Out:
# 0
# ('南昌', 122)
# 1
# ('深圳', 73)
# 2
# ('杭州', 61)
# 3
# ('广州', 61)
# 4
# ('成都', 55)
# 5
# ('南京', 32)
# 6
# ('苏州', 29)
# 7
# ('宁波', 28)
# 8
# ('朝阳', 28)
# 9
# ('武汉', 27)
# 10
# ('浦东新区', 25)
# 11
# ('长沙', 22)
# 12
# ('温州', 21)
# 13
# ('西安', 21)
# 14
# ('昆明', 17)
# 15
# ('青岛', 16)
# 16
# ('沈阳', 16)
# 17
# ('绍兴', 15)
# 18
# ('郑州', 15)
# 19
# ('哈尔滨', 14)
# 20
# ('无锡', 14)
# 21
# ('大连', 14)
# 22
# ('徐汇', 13)
# 23
# ('东城', 13)
# 24
# ('台州', 13)
# 25
# ('福州', 12)
# 26
# ('佛山', 11)
# 27
# ('静安', 10)
# 28
# ('厦门', 10)
# 29
# ('合肥', 9)
# 30
# ('闵行', 9)
# 31
# ('常州', 8)
# 32
# ('黄浦', 8)
# 33
# ('东莞', 8)
# 34
# ('金华', 7)
# 35
# ('泰州', 7)
# 36
# ('海口', 6)
# 37
# ('湖州', 6)
# 38
# ('宝山', 6)
# 39
# ('河西', 6)
# 40
# ('太原', 6)
# 41
# ('丰台', 6)
# 42
# ('呼和浩特', 6)
# 43
# ('通州', 5)
# 44
# ('江北', 5)
# 45
# ('济南', 5)
# 46
# ('扬州', 5)
# 47
# ('廊坊', 5)
# 48
# ('普陀', 5)
# 49
# ('赣州', 5)
# 50
# ('虹口', 4)
# 51
# ('鞍山', 4)
# 52
# ('珠海', 4)
# 53
# ('南宁', 4)
# 54
# ('闸北', 4)
# 55
# ('唐山', 4)
# 56
# ('盐城', 4)
# 57
# ('宜春', 4)
# 58
# ('洛阳', 4)
# 59
# ('长春', 4)
# 60
# ('抚州', 4)
# 61
# ('泉州', 4)
# 62
# ('松江', 3)
# 63
# ('杨浦', 3)
# 64
# ('烟台', 3)
# 65
# ('惠州', 3)
# 66
# ('通辽', 3)
# 67
# ('九江', 3)
# 68
# ('南开', 3)
# 69
# ('石家庄', 3)
# 70
# ('长宁', 3)
# 71
# ('漳州', 3)
# 72
# ('九龙坡', 3)
# 73
# ('鹰潭', 3)
# 74
# ('和平', 3)
# 75
# ('南通', 3)
# 76
# ('镇江', 3)
# 77
# ('江门', 3)
# 78
# ('威海', 3)
# 79
# ('嘉兴', 3)
# 80
# ('咸宁', 3)
# 81
# ('阜阳', 3)
# 82
# ('株洲', 3)
# 83
# ('连云港', 3)
# 84
# ('渝北', 3)
# 85
# ('安康', 3)
# 86
# ('玉林', 2)
# 87
# ('西青', 2)
# 88
# ('丹东', 2)
# 89
# ('龙岩', 2)
# 90
# ('上饶', 2)
# 91
# ('嘉定', 2)
# 92
# ('沙坪坝', 2)
# 93
# ('徐州', 2)
# 94
# ('河东', 2)
# 95
# ('南阳', 2)
# 96
# ('济宁', 2)
# 97
# ('韶关', 2)
# 98
# ('台北市', 2)
# 99
# ('揭阳', 2)
# 100
# ('北辰', 2)
# 101
# ('乌鲁木齐', 2)
# 102
# ('渝中', 2)
# 103
# ('淮北', 2)
# 104
# ('贵阳', 2)
# 105
# ('常德', 2)
# 106
# ('保定', 2)
# 107
# ('运城', 2)
# 108
# ('雅安', 2)
# 109
# ('大兴', 2)
# 110
# ('中山', 2)
# 111
# ('西城', 2)
# 112
# ('汕头', 2)
# 113
# ('吉林', 2)
# 114
# ('周口', 2)
# 115
# ('临汾', 2)
# 116
# ('恩施', 1)
# 117
# ('池州', 1)
# 118
# ('黄石', 1)
# 119
# ('衡阳', 1)
# 120
# ('庆阳', 1)
# 121
# ('遵义', 1)
# 122
# ('南平', 1)
# 123
# ('河北', 1)
# 124
# ('房山', 1)
# 125
# ('莆田', 1)
# 126
# ('武清', 1)
# 127
# ('齐齐哈尔', 1)
# 128
# ('邢台', 1)
# 129
# ('拉萨', 1)
# 130
# ('乌兰察布', 1)
# 131
# ('桂林', 1)
# 132
# ('日照', 1)
# 133
# ('鸡西', 1)
# 134
# ('景德镇', 1)
# 135
# ('北京', 1)
# 136
# ('荆州', 1)
# 137
# ('西宁', 1)
# 138
# ('平谷', 1)
# 139
# ('临沂', 1)
# 140
# ('七台河', 1)
# 141
# ('六盘水', 1)
# 142
# ('滨州', 1)
# 143
# ('岳阳', 1)
# 144
# ('锦州', 1)
# 145
# ('崇明', 1)
# 146
# ('石景山', 1)
# 147
# ('乐山', 1)
# 148
# ('大同', 1)
# 149
# ('湛江', 1)
# 150
# ('万宁', 1)
# 151
# ('宜宾', 1)
# 152
# ('绵阳', 1)
# 153
# ('宿迁', 1)
# 154
# ('德宏', 1)
# 155
# ('定安', 1)
# 156
# ('平顶山', 1)
# 157
# ('三亚', 1)
# 158
# ('绥化', 1)
# 159
# ('曲靖', 1)
# 160
# ('昌平', 1)
# 161
# ('东丽', 1)
# 162
# ('银川', 1)
# 163
# ('淄博', 1)
# 164
# ('渭南', 1)
# 165
# ('宜昌', 1)
# 166
# ('黄冈', 1)
# 167
# ('红桥', 1)
# 168
# ('阿拉尔', 1)
# 169
# ('毕节', 1)
# 170
# ('张家界', 1)
# 171
# ('清远', 1)
# 172
# ('琼海', 1)
# 173
# ('奉贤', 1)
# 174
# ('蚌埠', 1)
# 175
# ('湘西', 1)
# 176
# ('南充', 1)
# 177
# ('涪陵', 1)
# 178
# ('定西', 1)
# 179
# ('重庆', 1)
# 180
# ('潼南', 1)
# 181
# ('淮南', 1)
# 182
# ('静海', 1)
# 183
# ('佳木斯', 1)
# 184
# ('邵阳', 1)
# 185
# ('阜新', 1)
# 186
# ('南岸', 1)
# 187
# ('黑河', 1)
# 188
# ('沧州', 1)
# 189
# ('滨海新区', 1)
# 190
# ('克拉玛依', 1)
# 191
# ('梅州', 1)
# 192
# ('卢湾', 1)
# 193
# ('锡林郭勒', 1)
# 194
# ('潍坊', 1)
# 195
# ('广安', 1)
# 196
# ('陇南', 1)
# 197
# ('赤峰', 1)
# 198
# ('舟山', 1)
# 199
# ('眉山', 1)
# 200
# ('榆林', 1)
# 201
# ('青浦', 1)
# 202
# ('潮州', 1)
# 203
# ('兰州市', 1)
# 204
# ('吕梁', 1)
# 205
# ('资阳', 1)
# 206
# ('宁德', 1)
# 207
# ('柳州', 1)
# 208
# ('防城港', 1)
# 209
# ('衢州', 1)
# 210
# ('商丘', 1)
# 211
# ('贵港', 1)
# 212
# ('泰安', 1)
# 213
# ('文山', 1)
# 214
# ('邯郸', 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-74205f8cc575> in <module>()
#      48
#      49 if __name__ == '__main__':
# ---> 50     print(render())
#
# <ipython-input-135-74205f8cc575> in render()
#      44     geo.add('', attr, value, visual_range=[0, 500],
#      45             visual_text_color='#fff', symbol_size=15,
# ---> 46             is_visualmap=True, is_piecewise=True)
#      47     geo.render('好友位置分布.html')
#      48
#
# /anaconda3/lib/python3.5/site-packages/pyecharts/charts/geo.py in add(self, *args, **kwargs)
#      64
#      65     def add(self, *args, **kwargs):
# ---> 66         self.__add(*args, **kwargs)
#      67         return self
#      68
#
# /anaconda3/lib/python3.5/site-packages/pyecharts/charts/geo.py in __add(self, name, attr, value, type, maptype, coordinate_region, symbol_size, border_color, geo_normal_color, geo_emphasis_color, geo_cities_coords, is_roam, **kwargs)
#     129         for _name, _value in zip(attr, value):
#     130             _coordinate = self.get_coordinate(
# --> 131                 _name, coordinate_region, raise_exception=True
#     132             )
#     133             _data_value = [_coordinate[0], _coordinate[1], _value]
#
# /anaconda3/lib/python3.5/site-packages/pyecharts/charts/geo.py in get_coordinate(self, name, region, raise_exception)
#      59         coordinate = get_coordinate(name, region=region)
#      60         if coordinate is None and raise_exception:
# ---> 61             raise ValueError("No coordinate is specified for {}".format(name))
#      62
#      63         return coordinate
#
# ValueError: No coordinate is specified for 徐汇

# %%
import re
x = 'a12121assa'
x = '1我爱你1'
r1 = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
 
print(re.sub(r1, '', x))
# Out:
# 我爱你

# %%
# 导入jieba模块，用于中文分词
import jieba
# 导入matplotlib，用于生成2D图形
import matplotlib.pyplot as plt
# 导入wordcount，用于制作词云图
from wordcloud import WordCloud, STOPWORDS

# 获取所有个性签名
signatures = []
with open('friends.txt', mode='r', encoding='utf-8') as f:
    rows = f.readlines()
    for row in rows:
        signature = row.split(',')[5]
        if signature != '':
            signatures.append(signature)

# 设置分词
split = jieba.cut(str(signatures), cut_all=False)  # False精准模式分词、True全模式分词
words = ' '.join(split)  # 以空格进行拼接
# print(words)

# 设置屏蔽词，去除个性签名中的表情、特殊符号等
stopwords = STOPWORDS.copy()
stopwords.add('span')
stopwords.add('class')
stopwords.add('emoji')
stopwords.add('emoji1f334')
stopwords.add('emoji1f388')
stopwords.add('emoji1f33a')
stopwords.add('emoji1f33c')
stopwords.add('emoji1f633')

# 导入背景图
#bg_image = plt.imread('gp.jpg')

from scipy.misc import imread
b_mask = imread('ming.png')


wc=WordCloud(font_path='/anaconda3/lib/python3.5/site-packages/wordcloud/STKAITI.TTF', stopwords=stopwords,background_color='white', max_words=2000, mask=b_mask)
#wc.generate(cut_text)
#wc.to_file(“Good.jpg”)

# 设置词云参数，参数分别表示：画布宽高、背景颜色、背景图形状、字体、屏蔽词、最大词的字体大小
#wc = WordCloud(background_color='white', mask=bg_image, 
               #font_path='/anaconda3/lib/python3.5/site-packages/wordcloud/STKAITI.TTF',stopwords=stopwords,max_font_size=400, random_state=50)
#wc = WordCloud(width=1024, height=768, background_color='white', mask=bg_image, 
               #font_path='/anaconda3/lib/python3.5/site-packages/wordcloud/STKAITI.TTF',stopwords=stopwords, max_font_size=400, random_state=50)
# 将分词后数据传入云图
#wc.generate(words)
wc.generate_from_text(words)
plt.imshow(wc)  # 绘制图像
plt.axis('off')  # 不显示坐标轴
# 保存结果到本地
wc.to_file('个性签名词云图.png')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:37: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
from pyecharts import Map
value = [95.1, 23.2, 43.3, 66.4, 88.5, 0.1]
attr = [
   'China',
   'Canada',
   'Brazil',
   'Russia',
   'United States',
   'Unknown Country',
]
map_ = Map('世界地图示例', width=1200, height=600)
map_.add(
   '',
   attr,
   value,
   maptype='world',
   is_visualmap=True,
   visual_text_color='#000',
)
map_
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1fffc097abcd4d4e9a02bda7bd4f3ca3" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#
# var myChart_1fffc097abcd4d4e9a02bda7bd4f3ca3 = echarts.init(document.getElementById('1fffc097abcd4d4e9a02bda7bd4f3ca3'), 'light', {renderer: 'canvas'});
#
# var option_1fffc097abcd4d4e9a02bda7bd4f3ca3 = {
#     "legend": [
#         {
#             "orient": "horizontal",
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series": [
#         {
#             "showLegendSymbol": true,
#             "type": "map",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 95.1
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 23.2
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 43.3
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 66.4
#                 },
#                 {
#                     "name": "United States",
#                     "value": 88.5
#                 },
#                 {
#                     "name": "Unknown Country",
#                     "value": 0.1
#                 }
#             ],
#             "symbol": "circle",
#             "mapType": "world",
#             "roam": true
#         }
#     ],
#     "series_id": 7271931,
#     "animation": true,
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "\u4e16\u754c\u5730\u56fe\u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "visualMap": {
#         "calculable": true,
#         "type": "continuous",
#         "text": [
#             "high",
#             "low"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "max": 100,
#         "textStyle": {
#             "color": "#000"
#         },
#         "splitNumber": 5,
#         "left": "left",
#         "showLabel": true,
#         "min": 0,
#         "top": "bottom"
#     }
# };
# myChart_1fffc097abcd4d4e9a02bda7bd4f3ca3.setOption(option_1fffc097abcd4d4e9a02bda7bd4f3ca3);
#
#     });
# </script>

# %%
# 导入jieba模块，用于中文分词
import jieba
# 导入matplotlib，用于生成2D图形
import matplotlib.pyplot as plt
# 导入wordcount，用于制作词云图
from wordcloud import WordCloud, STOPWORDS

# 获取备注名
remarkNames = []
with open('friends.txt', mode='r', encoding='utf-8') as f:
    rows = f.readlines()
    for row in rows:
        remarkName = row.split(',')[1]
        if remarkName != '':
            remarkNames.append(remarkName)

# 设置分词
split = jieba.cut(str(remarkNames), cut_all=False)  # False精准模式分词、True全模式分词
words = ' '.join(split)  # 以空格进行拼接
#print(words)

# 导入背景图
from scipy.misc import imread
b_mask = imread('ming.png')


wc=WordCloud(font_path='/anaconda3/lib/python3.5/site-packages/wordcloud/STKAITI.TTF',background_color='white', max_words=2000, mask=b_mask)

# 设置词云参数，参数分别表示：画布宽高、背景颜色、背景图形状、字体、屏蔽词、最大词的字体大小
#wc = WordCloud(width=1024, height=768, background_color='white', mask=bg_image, font_path='/anaconda3/lib/python3.5/site-packages/wordcloud/STKAITI.TTF',
               #max_font_size=400, random_state=50)
# 将分词后数据传入云图
wc.generate_from_text(words)
plt.imshow(wc)  # 绘制图像
plt.axis('off')  # 不显示坐标轴
# 保存结果到本地
wc.to_file('备注名词云图.jpg')
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
from pyecharts import Bar

# 获取特殊好友
star_list = []  # 星标朋友
deny_see_list = []  # 不让他看我的朋友圈
no_see_list = []  # 不看他的朋友圈

with open('friends.txt', mode='r', encoding='utf-8') as f:
    rows = f.readlines()
    for row in rows:
        # # 获取好友名称
        name = row.split(',')[1] if row.split(',')[1] != '' else row.split(',')[0]
        # 获取星标朋友
        star = row.split(',')[6]
        if star == '1':
            star_list.append(name)
        # 获取设置了朋友圈权限的朋友
        flag = row.split(',')[7].replace('\n', '')
        if flag in ['259', '33027', '65795']:
            deny_see_list.append(name)
        if flag in ['65539', '65795']:
            no_see_list.append(name)

print('星标好友：', star_list)
print('不让他看我的朋友圈：', deny_see_list)
print('不看他的朋友圈：', no_see_list)

attr = ['星标朋友', '不让他看我的朋友圈', '不看他的朋友圈']
value = [len(star_list), len(deny_see_list), len(no_see_list)]

bar = Bar('特殊好友分析', '', title_pos='center')
bar.add('', attr, value, is_visualmap=True, is_label_show=True)
bar.render('特殊好友分析.html')
bar
# Out:
# 星标好友： []
# 不让他看我的朋友圈： []
# 不看他的朋友圈： ['Laffa Girl悉尼', '优品-营销号（广告号）', 'BASEBONE', '阿芳（创新吸塑包装）', '皇冠店搜aramer加新号ARAMER7', 'ADIDAS NIKE批发一件代发招代理', 'Alstonzzzzzzzzz', '悟小空', '上海（双喜）全国接单号', '噘噘嘴（无扰清粉）', '鞋世界', 'MD Ranking面岛爱购', '顾大师下单号', 'DearKey🌌', '凯🌐（人满注来意）', '赵妖镜', '澳洲  妮妮【批发，一件代发】', '韩国代购', 'Regents Park Pharmacy 药房💊', 'sherry🐨🌸', '燕子', 'San个Z 🦄🐾', 'ASH2a.Ashfield.凤雅堂', '米奇毛斯', '『PhX』💦  冠军北面找我接套现', 'sally（杨秀钰）', '👑YUYA_JAPAN買手店🇯🇵㍿', 'Tim Zhang', 'Amy', '小南15800329561', '诚信人鞋业', 'A、Fenrir 回复慢见谅', 'A一品香·重庆1号小服（已满）', '生活概念', 'AAA潮人不会飞', '🌸孔小可🌸', '王轶男', 'balen吧主', '微时代来了', '李鸿赟', 'jasonwood@', '泽宇ོ', '两只考拉🐨🐨客服1', '四格123 人满 请加rbmsrjjj', '薛司南', '小妖 Ő . Ő 厂长麻麻派我来巡山', '小饼@0601', '💍Okey-Dokey-Yo. 💎', 'RAINF', '原价帝', '一个k咧fei', 'A0A🍻 好吃的螺蛳', 'British Boy 1960', '凯大王🌜', '༄Ꮩ࿆Ꭵ࿆Ꮲ࿆瑶ི❁҉҉҉҉҉҉', 'April💃澳乐维他#\U0001f91d 总客服号', '小G-有事留言', 'CC购 LinkCA国际 主客服', ' Alice 姚', 'TRENDIANO南昌红谷滩万达', '布村Bill', '指南针🍻麻辣小师妹', 'fang fang', 'Dade-欢迎各大电商合作\U0001f91d', '张文秀', '詹密', '杨洋', 'Doris 丹', '小毛毛', 'Jojo🍉', '特别的人', 'Edison__Chen 💍', 'youngxlord', '贺哥哥·MIKI', 'G💤', '婷婷（时差3小时）', 'Hello.树先生🐰客服2', '崔M昌', '情开，夏末（日韩澳代购）', '熊哥', 'か', 'YHW', 'Nancy@CWH澳洲大药房', 'Kore', '资本', 'aumake', '多喝热水', 'Bloody Mary🍋', '李志刚', '墨迹', '瑞嘉社工-玲', 'Charles J', '田凯文', '暖风', '^_^Miss.花花。在澳洲', '澳有VIP客服（vip群咨询下单）', 'SM', '爘', '什么叫惊喜。', 'Sammie⛱', 'Jia', 'Amy-人在澳洲，有时差', '哈哈2', '小zhan（澳品代购）', '澳森', '泽宁', 'ldefu', 'Poison、1573', '林卡咖啡-YoYo', 'Eileen ', '江财钟老师', 'Walking \U0001f95d Pancake', 'pig奴奴', '静', '小唐翻译', '坛子', '婷婷', '夏日倾情', '可乐加冰吗', 'city girls', '国民汇12点-7点，周六休息', '33度澳洲精品馆-客服', 'Danny_DNA全球购', 'Steven', 'Walker US9', 'orcHid丶', '我就是鞋神', 'FrankLiu🍭', '🦄杨宗烨', '糖衣果果-Candy', 'AA.不二穿正品', 'White Hat', '徐凤年', '꧁S i s s i꧂', '🔱 小姐姐', '💋  Victoria', 'MWEIiii-', '顺7。自然', '凯丽', '\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000', 'お娟🌸', '幸福手册美学教育～杨芸', 'Scum', '超超✨', 'Lao干妈🌍', 'Green_♠️', '宁晓昕', 'MORES 客服2号', '熊宝_悉尼平台2🎉', '\u3000\u3000\u3000\u3000\u3000\u3000\u3000', '阿源', 'a国际头等舱商务舱机票--魏涛', '🐝Gina澳产帮帮买🐝', 'Love', 'L°零度', '熊-', '磁场名品同行主号-支持信用卡', '菲', '领航MK职培小助手', 'Painkiller', '余笙的旅行杂货铺', '阿杨恭喜发财', '李彩萍', 'Tcc', 'A.徐涛', 'autocad2007', '智坤', '【PD】', 'Lin༻', 'ω 饭饭•. ω 汤汤~', 'W.YUE', 'L.', 'TT_御姐', 'Libra（想起飞）', '永隔三秋梦 ', 'susan xian', 'sʟɪᴘᴋɴᴏᴛ', 'Ethanism', 'Lucrecia -- Migration agent', '百分百被🔪👏㍿', '悠悠互转平台', '帆', 'NUT💨', '风一样自由', 'ᎢᎯᏁᎶ', '🐳Onkle【朋友圈皆可口】', '全国空放📍当天放款(纯线上)', '果粒橙', '傲娇的草泥马🐎', '(˶‾᷄ ⁻̫ ‾᷅˵)🐰肥花', '天天', 'xl', '三克油™', 'ღ_小阿婷Girl🌶套现+手机壳📱', 'AxySɨk', '叶子🍃', '香烟专卖', '🌚', 'A_Honey Garlic Spareribs🍖', '💋 毒药', 'Sunny', '江湖儿女少女霜', '玩具槍与玫瑰🍁', '朱瑜|吖咪战略合伙人', '花里🌸美甲美睫纹绣', '不會起名', '悉尼妈妈🇦🇺Lankey', 'Yzww_Lab16（感谢推荐好友）', 'TON YOUZS', '咩咩咩🐔咩咩咩', '风哀_Sherry', 'jimmy kudo', '椰汁🌴绵绵冰🍧', '🍄', '沐纹画.Tattoo主理人-沐子', 'H、xin', '胡俊|HHD|相馬🇨🇳設計', '🉐', 'Aaron.Chen', '「周染然」', 'A🍀乐乎澳洲代购💚', 'AOM🐟', '郭蕾', '¨̮', '不停.', 'ow张修瑶', 'BADA$$CUSTOM🌎', 'zthhhh', 'Blue', 'cd', 'Vsop', '                    🐟🐟🐟', 'Howard Lee', '刘星何', '胖豆芽', '春花夏叶', '果皮蛋蛋', 'Sudan🔥', '艺人-King₁₈₈₅₉₀₇₅₅₀₇', 'Sha_', 'Ac', '🍬 honey🍬 陈', '金木 研', 'King Roland', 'Web.li', '衰仔华', 'George', 'jia55', "⭕️'Aska🐲張✨", 'SongKeyyy', '🎀孟园🐱M🐾', '维娜蒂天空', 'AJ_靠谱青年', 'Y', '💭瑶瑶', '🎶LEE', '子侨🌺Sharon', 'JimmyZ💣', '全球Go', '陌芊TARA 🍉 ow19短袖吴亦凡夹克', 'The One', '耶小贱', 'Chen#', 'UGG  Ashfied，', '🍀晶', '赵付小樱', '天天tian：）', '大咖龙虾（九方店8215188）', '谷力特', 'Dre', '澳洲大长腿', '丝概造型-熊俊', 'SupermanLee 请星标 请转ZFB', '释然⁶⁶⁶⁶(只卖真货)', '吴浪浪', '信皓翔 🌍', '顾文瀚', '我薯片🍟', 'Jacky 2号', 'UK9', '空白', '美晴生鲜一招商仁和', '做不大的EDwin', 'ɪммɢᴅ', '袁博', 'Aken🎵', 'Wainne', 'UK6.5-7 XS XS', '林默🌹', 'Y L', '黎明不是张学友（星标我）', '。', '14', '顶悦-郭庆志', '一个做贷款的姑娘🚗蓉蓉', '宽肩', '阿大大大🍓', 'Z', '花糖💋', 'Demi🐰', '齐', '+8618685101915', '💦俊&amp;俊💦', 'VEI', '夏日荷花', 'Alstonzz', 'Tracy 🍒', '卿小凡', '花园宝宝', 'Hyde', '问不回', '草莓少女一号店®', '我干我的羊', '椰叔（本人）一号线', '网易云侯土鳖🐒', '👺小君👺', 'Barry', '小达', 'KAIII.🌾(考试周回复慢)', 'Derek.', 'sutong', '🌸Ada💋', 'dan-freeman+', '@JY（', 'Steven.Wen（感谢推荐 请您星标', 'Millionaires', 'LQ', '杨小爬🍁', '小米蛋糕℡¹³⁵⁰⁷⁰⁸²¹²⁶', '夏伤', 'chouhai', '疯子和诗', 'AL Ze', 'Jacco', 'Hide on bush', '悉尼妈妈文案号LIN', 'LEO🇪🇺备用号：geezii', '近我者富-黄安妮', 'Michelle', 'bgc董肇睿', '淏翰instyle', 'Kkvve', 'FAKAN ...
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d278425f226d4b3daa2a088aacdffee8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d278425f226d4b3daa2a088aacdffee8 = echarts.init(document.getElementById('d278425f226d4b3daa2a088aacdffee8'), 'light', {renderer: 'canvas'});
#
# var option_d278425f226d4b3daa2a088aacdffee8 = {
#     "legend": [
#         {
#             "orient": "horizontal",
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "splitLine": {
#                 "show": true
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "show": true,
#             "inverse": false,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8
#             }
#         }
#     ],
#     "series_id": 3368901,
#     "series": [
#         {
#             "type": "bar",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": true
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "seriesId": 3368901,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "data": [
#                 0,
#                 0,
#                 454
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "center",
#             "text": "\u7279\u6b8a\u597d\u53cb\u5206\u6790",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "category",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "data": [
#                 "\u661f\u6807\u670b\u53cb",
#                 "\u4e0d\u8ba9\u4ed6\u770b\u6211\u7684\u670b\u53cb\u5708",
#                 "\u4e0d\u770b\u4ed6\u7684\u670b\u53cb\u5708"
#             ],
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "inverse": false,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "visualMap": {
#         "calculable": true,
#         "type": "continuous",
#         "text": [
#             "high",
#             "low"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "max": 100,
#         "textStyle": {},
#         "splitNumber": 5,
#         "left": "left",
#         "showLabel": true,
#         "min": 0,
#         "top": "bottom"
#     }
# };
# myChart_d278425f226d4b3daa2a088aacdffee8.setOption(option_d278425f226d4b3daa2a088aacdffee8);
#
#     });
# </script>

# %%
import itchat
import os

# 获取数据
def get_image():
    itchat.auto_login()
    friends = itchat.get_friends(update=True)

    #  在当前位置创建一个用于存储头像的目录headImages
    base_path = 'headImages'
    if not os.path.exists(base_path):
        os.mkdir(base_path)

    # 获取所有好友头像
    for friend in friends:
        img_data = itchat.get_head_img(userName=friend['UserName'])  # 获取头像数据
        img_name = friend['RemarkName'] if friend['RemarkName'] != '' else friend['NickName']
        img_file = os.path.join(base_path, img_name + '.jpg')
        print(img_file)
        with open(img_file, 'wb') as file:
            file.write(img_data)

if __name__ == '__main__':
    get_data()
# Out:
# Getting uuid of QR code.
# INFO:itchat:Getting uuid of QR code.
# Downloading QR code.
# INFO:itchat:Downloading QR code.
# Please scan the QR code to log in.
# INFO:itchat:Please scan the QR code to log in.
# Please press confirm on your phone.
# INFO:itchat:Please press confirm on your phone.
# Loading the contact, this may take a little while.
# INFO:itchat:Loading the contact, this may take a little while.
# Login successfully as WAKE UP
# INFO:itchat:Login successfully as WAKE UP
# LOG OUT!
# INFO:itchat:LOG OUT!
